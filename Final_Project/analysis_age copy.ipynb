# %% [markdown]
# ## Final Project
#
# ### Analysis of features extarcted from audio data
#
# - link to dataset:
#
# ### Motivation and Goals
#
# The goal of this project is to clasdify voice recoridngs as either male of female, based on numerical features extracted from the Mozilla common voice dataset.
# The purpose of this project is ...

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from prettytable import PrettyTable
import os
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer   
from sklearn.compose import make_column_selector
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from playsound import playsound
from sklearn.model_selection import cross_val_score, KFold
from sklearn.pipeline import make_pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.base import clone
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.svm import LinearSVC
from tqdm import tqdm
from sklearn.metrics import (
    roc_auc_score, log_loss, RocCurveDisplay
)
from sklearn.calibration import calibration_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from sklearn.multioutput import MultiOutputClassifier
#!pip install mord
from mord import LogisticAT


FULL_RUN=False

# %% [markdown]
# ## Data Loading

# %%
list_of_files = ["data_en_5.csv", "data_de_5.csv", "data_es_5.csv", "data_fr_5.csv", "data_da_5.csv", "data_se_5.csv"]
folder_path = "./data/"
data_frames = []

for file_name in list_of_files:
    file_path = os.path.join(folder_path, file_name)
    if os.path.exists(file_path):
        with open(file_path, "r") as file:
            data_frames.append(pd.read_csv(file, dtype={3: str}))

data_raw = pd.concat(data_frames, ignore_index=True)

data_raw.head()
# Out:
#                                            client_id  \
# 0  00015e9c3555dafee96d32f38408877b6c33cc7668c5c7...
# 1  00015e9c3555dafee96d32f38408877b6c33cc7668c5c7...
# 2  00015e9c3555dafee96d32f38408877b6c33cc7668c5c7...
# 3  00015e9c3555dafee96d32f38408877b6c33cc7668c5c7...
# 4  00015e9c3555dafee96d32f38408877b6c33cc7668c5c7...
#
#                                  path sentence sentence_domain       age  \
# 0  clips/common_voice_en_22070055.mp3      Hey             NaN  twenties
# 1  clips/common_voice_en_22070053.mp3       no             NaN  twenties
# 2  clips/common_voice_en_22070105.mp3     five             NaN  twenties
# 3  clips/common_voice_en_22070052.mp3     nine             NaN  twenties
# 4  clips/common_voice_en_22070093.mp3  Firefox             NaN  twenties
#
#            gender                                            accents locale  \
# 0  male_masculine  India and South Asia (India, Pakistan, Sri Lanka)     en
# 1  male_masculine  India and South Asia (India, Pakistan, Sri Lanka)     en
# 2  male_masculine  India and South Asia (India, Pakistan, Sri Lanka)     en
# 3  male_masculine  India and South Asia (India, Pakistan, Sri Lanka)     en
# 4  male_masculine  India and South Asia (India, Pakistan, Sri Lanka)     en
#
#    mfcc_01_mean  mfcc_02_mean  ...  spec_contrast_band_4_std  \
# 0     -346.5183      105.7667  ...                    3.4268
# 1     -322.9995      126.3259  ...                    4.2800
# 2     -331.8177      117.0118  ...                    4.2195
# 3     -332.4990      135.0629  ...                    4.0191
# 4     -338.9404      107.3492  ...                    4.2380
#
#    spec_contrast_band_5_std  spec_contrast_band_6_std  \
# 0                    4.6326                    4.5448
# 1                    3.4086                    2.3813
# 2                    3.7854                    2.1500
# 3                    3.4954                    1.7384
# 4                    3.7370                    4.5819
#
#    spec_contrast_band_7_std  spec_rolloff_mean  spec_rolloff_std  zcr_mean  \
# 0                    3.9582          8989.2134         3783.7087    0.0906
# 1                    4.6293          7763.4465         3417.3246    0.0667
# 2                    4.7605          9540.2672         3227.2135    0.1061
# 3                    3.2659          8103.4007         2729.2759    0.0655
# 4                    4.2291          9500.3952         3109.5243    0.1160
#
#    zcr_std  rmse_mean  rmse_std
# 0   0.0421     0.0605    0.1144
# 1   0.0324     0.0491    0.0848
# 2   0.0389     0.0291    0.0574
# 3   0.0273     0.0269    0.0421
# 4   0.0543     0.0293    0.0539
#
# [5 rows x 96 columns]

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183670 entries, 0 to 183669
# Data columns (total 96 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   client_id                  183670 non-null  object
#  1   path                       183670 non-null  object
#  2   sentence                   183595 non-null  object
#  3   sentence_domain            24 non-null      object
#  4   age                        182568 non-null  object
#  5   gender                     183670 non-null  object
#  6   accents                    131636 non-null  object
#  7   locale                     183670 non-null  object
#  8   mfcc_01_mean               183670 non-null  float64
#  9   mfcc_02_mean               183670 non-null  float64
#  10  mfcc_03_mean               183670 non-null  float64
#  11  mfcc_04_mean               183670 non-null  float64
#  12  mfcc_05_mean               183670 non-null  float64
#  13  mfcc_06_mean               183670 non-null  float64
#  14  mfcc_07_mean               183670 non-null  float64
#  15  mfcc_08_mean               183670 non-null  float64
#  16  mfcc_09_mean               183670 non-null  float64
#  17  mfcc_10_mean               183670 non-null  float64
#  18  mfcc_11_mean               183670 non-null  float64
#  19  mfcc_12_mean               183670 non-null  float64
#  20  mfcc_13_mean               183670 non-null  float64
#  21  mfcc_14_mean               183670 non-null  float64
#  22  mfcc_15_mean               183670 non-null  float64
#  23  mfcc_16_mean               183670 non-null  float64
#  24  mfcc_17_mean               183670 non-null  float64
#  25  mfcc_18_mean               183670 non-null  float64
#  26  mfcc_19_mean               183670 non-null  float64
#  27  mfcc_20_mean               183670 non-null  float64
#  28  mfcc_01_std                183670 non-null  float64
#  29  mfcc_02_std                183670 non-null  float64
#  30  mfcc_03_std                183670 non-null  float64
#  31  mfcc_04_std                183670 non-null  float64
#  32  mfcc_05_std                183670 non-null  float64
#  33  mfcc_06_std                183670 non-null  float64
#  34  mfcc_07_std                183670 non-null  float64
#  35  mfcc_08_std                183670 non-null  float64
#  36  mfcc_09_std                183670 non-null  float64
#  37  mfcc_10_std                183670 non-null  float64
#  38  mfcc_11_std                183670 non-null  float64
#  39  mfcc_12_std                183670 non-null  float64
#  40  mfcc_13_std                183670 non-null  float64
#  41  mfcc_14_std                183670 non-null  float64
#  42  mfcc_15_std                183670 non-null  float64
#  43  mfcc_16_std                183670 non-null  float64
#  44  mfcc_17_std                183670 non-null  float64
#  45  mfcc_18_std                183670 non-null  float64
#  46  mfcc_19_std                183670 non-null  float64
#  47  mfcc_20_std                183670 non-null  float64
#  48  chroma_01_mean             183670 non-null  float64
#  49  chroma_02_mean             183670 non-null  float64
#  50  chroma_03_mean             183670 non-null  float64
#  51  chroma_04_mean             183670 non-null  float64
#  52  chroma_05_mean             183670 non-null  float64
#  53  chroma_06_mean             183670 non-null  float64
#  54  chroma_07_mean             183670 non-null  float64
#  55  chroma_08_mean             183670 non-null  float64
#  56  chroma_09_mean             183670 non-null  float64
#  57  chroma_10_mean             183670 non-null  float64
#  58  chroma_11_mean             183670 non-null  float64
#  59  chroma_12_mean             183670 non-null  float64
#  60  chroma_01_std              183670 non-null  float64
#  61  chroma_02_std              183670 non-null  float64
#  62  chroma_03_std              183670 non-null  float64
#  63  chroma_04_std              183670 non-null  float64
#  64  chroma_05_std              183670 non-null  float64
#  65  chroma_06_std              183670 non-null  float64
#  66  chroma_07_std              183670 non-null  float64
#  67  chroma_08_std              183670 non-null  float64
#  68  chroma_09_std              183670 non-null  float64
#  69  chroma_10_std              183670 non-null  float64
#  70  chroma_11_std              183670 non-null  float64
#  71  chroma_12_std              183670 non-null  float64
#  72  spec_centroid_mean         183670 non-null  float64
#  73  spec_centroid_std          183670 non-null  float64
#  74  spec_bandwidth_mean        183670 non-null  float64
#  75  spec_bandwidth_std         183670 non-null  float64
#  76  spec_contrast_band_1_mean  183670 non-null  float64
#  77  spec_contrast_band_2_mean  183670 non-null  float64
#  78  spec_contrast_band_3_mean  183670 non-null  float64
#  79  spec_contrast_band_4_mean  183670 non-null  float64
#  80  spec_contrast_band_5_mean  183670 non-null  float64
#  81  spec_contrast_band_6_mean  183670 non-null  float64
#  82  spec_contrast_band_7_mean  183670 non-null  float64
#  83  spec_contrast_band_1_std   183670 non-null  float64
#  84  spec_contrast_band_2_std   183670 non-null  float64
#  85  spec_contrast_band_3_std   183670 non-null  float64
#  86  spec_contrast_band_4_std   183670 non-null  float64
#  87  spec_contrast_band_5_std   183670 non-null  float64
#  88  spec_contrast_band_6_std   183670 non-null  float64
#  89  spec_contrast_band_7_std   183670 non-null  float64
#  90  spec_rolloff_mean          183670 non-null  float64
#  91  spec_rolloff_std           183670 non-null  float64
#  92  zcr_mean                   183670 non-null  float64
#  93  zcr_std                    183670 non-null  float64
#  94  rmse_mean                  183670 non-null  float64
#  95  rmse_std                   183670 non-null  float64
# dtypes: float64(88), object(8)
# memory usage: 134.5+ MB

# %%
data_raw.describe(include="all")
# Out:
#                                                 client_id  \
# count                                              183670
# unique                                              36738
# top     3033341a33d4bb34ad34aa7444c859748ed9cabe7364d8...
# freq                                                   20
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          path sentence sentence_domain  \
# count                                  183670   183595              24
# unique                                 183670   140372              10
# top     clips/common_voice_sv-SE_25750576.mp3  Firefox         general
# freq                                        1      869              10
# mean                                      NaN      NaN             NaN
# std                                       NaN      NaN             NaN
# min                                       NaN      NaN             NaN
# 25%                                       NaN      NaN             NaN
# 50%                                       NaN      NaN             NaN
# 75%                                       NaN      NaN             NaN
# max                                       NaN      NaN             NaN
#
#              age          gender                accents  locale  \
# count     182568          183670                 131636  183670
# unique         9               2                    658       6
# top     twenties  male_masculine  United States English      en
# freq       74945          143330                  35715  106233
# mean         NaN             NaN                    NaN     NaN
# std          NaN             NaN                    NaN     NaN
# min          NaN             NaN                    NaN     NaN
# 25%          NaN             NaN                    NaN     NaN
# 50%          NaN             NaN                    NaN     NaN
# 75%          NaN             NaN                    NaN     NaN
# max          NaN             NaN                    NaN     NaN
#
#          mfcc_01_mean   mfcc_02_mean  ...  spec_contrast_band_4_std  \
# count   183670.000000  183670.000000  ...             183670.000000
# unique            NaN            NaN  ...                       NaN
# top               NaN            NaN  ...                       NaN
# freq              NaN            NaN  ...                       NaN
# mean      -433.083453     106.725027  ...                  4.619814
# std         92.895697      27.527274  ...                  0.773090
# min      -1131.370972      -8.795303  ...                  0.000000
# 25%       -479.824127      89.726835  ...                  4.084150
# 50%       -417.808914     107.633327  ...                  4.525914
# 75%       -372.730217     124.976196  ...                  5.061872
# max         -7.622044     242.315399  ...                 12.416712
#
#         spec_contrast_band_5_std  spec_contrast_band_6_std  \
# count              183670.000000             183670.000000
# unique                       NaN                       NaN
# top                          NaN                       NaN
# freq                         NaN                       NaN
# mean                    4.847164                  6.921225
# std                     0.951920                  2.099385
# min                     0.000000                  0.000000
# 25%                     4.195326                  5.468441
# 50%                     4.711573                  6.732120
# 75%                     5.361510                  8.165126
# max                    13.110107                 22.740114
#
#         spec_contrast_band_7_std  spec_rolloff_mean  spec_rolloff_std  \
# count              183670.000000      183670.000000     183670.000000
# unique                       NaN                NaN               NaN
# top                          NaN                NaN               NaN
# freq                         NaN                NaN               NaN
# mean                    6.550476        4920.925742       2871.320474
# std                     2.942824        1824.650639        989.775650
# min                     0.000000           0.000000          0.000000
# 25%                     4.796036        3611.233885       2097.006988
# 50%                     5.815831        4602.441790       2794.098861
# 75%                     7.197205        5952.463468       3543.561115
# max                    26.842926       16119.900628       6846.182433
#
#              zcr_mean        zcr_std      rmse_mean       rmse_std
# count   183670.000000  183670.000000  183670.000000  183670.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         0.084152       0.071973       0.047341       0.053646
# std          0.039789       0.028838       0.035350       0.033410
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.055889       0.051305       0.022227       0.028345
# 50%          0.077148       0.068592       0.041500       0.050502
# 75%          0.104689       0.089774       0.064625       0.073442
# max          0.626986       0.294794       0.558873       0.317272
#
# [11 rows x 96 columns]

# %%
data_raw["age"].unique()
# Out:
# array(['twenties', 'teens', 'thirties', 'fourties', 'fifties', 'sixties',
#        nan, 'seventies', 'eighties', 'nineties'], dtype=object)

# %%
with open("./data/WORLD-2024.csv", "r") as file:
    world_population_raw = pd.read_csv(file)

def map_to_bin(age_range):
    try:
        lower = int(age_range.split('-')[0])
    except (ValueError, IndexError):
        return None
    return (lower // 10) * 10

world_population = world_population_raw.copy()
world_population['age'] = world_population_raw['Age'].apply(map_to_bin)
world_population['count'] = world_population['M'] + world_population['F']

world_population=world_population.groupby('age', as_index=False)[['M', 'F', 'count']].sum()

print("Global population by age group")
world_population_table= PrettyTable()
world_population_table.field_names = ["Age", "F", "M", "Count"]
for age in world_population["age"].unique():
    female= world_population[world_population["age"] == age]["F"].values[0]
    male= world_population[world_population["age"] == age]["M"].values[0]
    count = world_population[world_population["age"] == age]["count"].values[0]
    world_population_table.add_row([age, female, male, count])
print(world_population_table)

world_population= world_population[(world_population["age"] > 0)&(world_population["age"] < 100)]
world_population['percentage_f'] = world_population['F'] / world_population['count'].sum()
world_population['percentage_m'] = world_population['M'] / world_population['count'].sum()

world_population_table= PrettyTable()
world_population_table.field_names = ["Age", "Count", "Percentage - Female", "Percentage - Male"]
for age in world_population["age"].unique():
    count = world_population[world_population["age"] == age]["count"].values[0]
    percentage_f = np.round(world_population[world_population["age"] == age]["percentage_f"].values[0]*100,2)
    percentage_m = np.round(world_population[world_population["age"] == age]["percentage_m"].values[0]*100,2)
    world_population_table.add_row([age, count, percentage_f, percentage_m])
print(world_population_table)
# Out:
# Global population by age group
# +------+-----------+-----------+------------+
# | Age  |     F     |     M     |   Count    |
# +------+-----------+-----------+------------+
# | 0.0  | 647571780 | 683880297 | 1331452077 |
# | 10.0 | 646940513 | 689549048 | 1336489561 |
# | 20.0 | 591939467 | 627801903 | 1219741370 |
# | 30.0 | 583727408 | 612129215 | 1195856623 |
# | 40.0 | 499876584 | 511145211 | 1011021795 |
# | 50.0 | 444383233 | 438029375 | 882412608  |
# | 60.0 | 335349756 | 308707292 | 644057048  |
# | 70.0 | 207266969 | 169569804 | 376836773  |
# | 80.0 |  84361120 |  55509075 | 139870195  |
# | 90.0 |  16467366 |  7180149  |  23647515  |
# +------+-----------+-----------+------------+
# +------+------------+---------------------+-------------------+
# | Age  |   Count    | Percentage - Female | Percentage - Male |
# +------+------------+---------------------+-------------------+
# | 10.0 | 1336489561 |         9.47        |        10.1       |
# | 20.0 | 1219741370 |         8.67        |        9.19       |
# | 30.0 | 1195856623 |         8.55        |        8.96       |
# | 40.0 | 1011021795 |         7.32        |        7.48       |
# | 50.0 | 882412608  |         6.51        |        6.41       |
# | 60.0 | 644057048  |         4.91        |        4.52       |
# | 70.0 | 376836773  |         3.03        |        2.48       |
# | 80.0 | 139870195  |         1.24        |        0.81       |
# | 90.0 |  23647515  |         0.24        |        0.11       |
# +------+------------+---------------------+-------------------+

# %%
def transform_age(age):
    if age=="teens":
        return 10
    elif age=="twenties":
        return 20
    elif age=="thirties":
        return 30
    elif age=="fourties":
        return 40
    elif age=="fifties":
        return 50
    elif age=="sixties":
        return 60
    elif age=="seventies":
        return 70
    elif age=="eighties":
        return 80
    elif age=="nineties":
        return 90
    elif isinstance(age, (int, float)):
        return age
    else:
        return None

data_raw["age"] = data_raw["age"].apply(transform_age)
print(f'dropped {data_raw["age"].isnull().sum()} rows')
data_raw = data_raw.dropna(subset=["age"])

# print counts
def generate_age_count_table(df):
    """
    Function to generate a PrettyTable with age counts
    :param df: DataFrame containing an 'age' column
    :return: PrettyTable object
    """
    table = PrettyTable()
    table.field_names = ["Age", "F", "M", "Count"]
    for age in sorted(df["age"].unique()):
        female_count = df[(df["age"] == age) & (df["gender"] == "female_feminine")].shape[0]
        male_count = df[(df["age"] == age) & (df["gender"] =="male_masculine")].shape[0]
        count = df[df["age"] == age].shape[0]
        table.add_row([age,female_count, male_count, count])
    return table

# Generate and print the table
table = generate_age_count_table(data_raw)
print(table)
# Out:
# dropped 1102 rows
# +------+-------+-------+-------+
# | Age  |   F   |   M   | Count |
# +------+-------+-------+-------+
# | 10.0 |  4652 | 16107 | 20759 |
# | 20.0 | 15995 | 58950 | 74945 |
# | 30.0 |  7393 | 32188 | 39581 |
# | 40.0 |  4698 | 18513 | 23211 |
# | 50.0 |  4434 |  9781 | 14215 |
# | 60.0 |  2206 |  4969 |  7175 |
# | 70.0 |  591  |  1779 |  2370 |
# | 80.0 |   52  |  231  |  283  |
# | 90.0 |   0   |   29  |   29  |
# +------+-------+-------+-------+

# %%
# Create age_young_old column
data_raw['age_young_old'] = data_raw['age'].apply(lambda x: 'young' if x <= 30 else ('old' if x >= 40 else 'middle'))

# Create age_3_bins column
def categorize_age_3_bins(age):
    if age < 30:
        return '10-29'
    elif age < 50:
        return '30-49'
    else:
        return '50+'

data_raw['age_3_bins'] = data_raw['age'].apply(categorize_age_3_bins)

# Display the first few rows to verify
data_raw[['age', 'age_young_old', 'age_3_bins']].head()
# Out:
#     age age_young_old age_3_bins
# 0  20.0         young      10-29
# 1  20.0         young      10-29
# 2  20.0         young      10-29
# 3  20.0         young      10-29
# 4  20.0         young      10-29

# %%
def histograms(data):
    """
    Function to plot histograms of the dataframe
    :param data: DataFrame
    :return: None
    """
    data.hist(figsize=(20, 20), bins=50, color='black')
    plt.suptitle('Histograms (50 bins) of all features', fontsize=20)
    plt.tight_layout(rect=[0, 0, 1, 0.98])
    plt.show()
    
if FULL_RUN:   
    histograms(data_raw)

# %%
# histograms by gender
def histogram_by_gender(feature):
    
    female_feminine = data_raw['gender'] == 'female_feminine'
    feature_female = feature[female_feminine]
    
    male_masculine = data_raw['gender'] == 'male_masculine'
    feature_male = feature[male_masculine]
    
    plt.figure(figsize=(10, 5))
    plt.hist(feature_female, bins=50, color='pink', alpha=0.5)
    plt.hist(feature_male, bins=50, color='blue', alpha=0.5)
    plt.title(f'Histogram of {feature.columns[0]}')
    plt.show()

if FULL_RUN: 
    histogram_by_gender(data_raw[['spec_bandwidth_mean']])
    histogram_by_gender(data_raw[['spec_contrast_band_1_mean']])

# %%
col_to_log_transform = ['spec_contrast_band_7_mean', 'spec_contrast_band_7_std', 'rmse_mean', 'rmse_std']

# %%
# drop sentence_domain & exclude duplicate speakers
try:
    data_sampled = data_raw.groupby("client_id", group_keys=False, include_groups=False).apply(
        lambda g: pd.concat([g.drop_duplicates("locale").head(5), g.head(5 - len(g.drop_duplicates("locale")))])
    )
    # data_sampled = data_raw[data_raw["locale"] == "en"]
    data_sampled = data_sampled.drop(columns=["sentence_domain"])
except KeyError:
    print("Column sentence_domain already dropped")
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_37284\4268570829.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data_sampled = data_raw.groupby("client_id", group_keys=False).apply(

# %%
log_rmse = np.log(data_sampled['rmse_mean'] + 1e-10)


# First histogram
if FULL_RUN:
    fig, axes = plt.subplots(1, 2, figsize=(16, 8))
    log_rmse.hist(bins=200, ax=axes[0], color='black')
    # data_raw['rmse_mean'].hist(bins=200, ax=axes[0], color='black')
    axes[0].set_title('Before Dropping Quiet Audio Files')

# IQR-based outlier detection
Q1 = log_rmse.quantile(0.25)
Q3 = log_rmse.quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(f"Lower Bound:{lower_bound}")
print(f"Upper Bound:{upper_bound}")

# Apply bounds to filter data
mask_inliers = (log_rmse >= lower_bound) & (log_rmse <= upper_bound)
data_clean = data_sampled[mask_inliers]

# Dropping quiet audio files
#bool_mask_quiet = data_sampled["rmse_mean"] < 0.001
#data_clean = data_sampled[~bool_mask_quiet]
print(f"Samples dropped: {data_sampled.shape[0]-data_clean.shape[0]}")
print(f"Samples left: {data_clean.shape[0]}")

# Second histogram
if FULL_RUN:
    np.log(data_clean['rmse_mean'] + 1e-10).hist(bins=200, ax=axes[1], color='black')
    # data_raw['rmse_mean'].hist(bins=200, ax=axes[1], color='black')
    axes[1].set_title('After Dropping Quiet Audio Files')

    plt.suptitle('Logarithm of rmse_mean', fontsize=20)
    plt.tight_layout(rect=[0, 0, 1, 0.98])
    plt.show()
# Out:
# Lower Bound:-5.460270548727399
# Upper Bound:-1.1281796576427836
# Samples dropped: 6211
# Samples left: 170589

# %%
""" #Undersample based on the demographic data
data_reduced = pd.DataFrame(columns=data_raw.columns)
for age in demographically_based_count["age"].unique():
    
    count_f = demographically_based_count[demographically_based_count["age"] == age]["count_f"].values[0].astype(int)
    count_m = demographically_based_count[demographically_based_count["age"] == age]["count_m"].values[0].astype(int)
    age_group_f = data_raw[(data_raw["age"] == age) & (data_raw["gender"] =="female_feminine")]
    age_group_m = data_raw[(data_raw["age"] == age) & (data_raw["gender"] =="male_masculine")]
    if len(age_group_f) > count_f:
        age_group_f = age_group_f.sample(n=count_f, random_state=27)
    if len(age_group_m) > count_m:
        age_group_m = age_group_m.sample(n=count_m, random_state=27)
    data_reduced = pd.concat([data_reduced, age_group_f, age_group_m], ignore_index=True)
data_reduced = data_reduced.sample(frac=1, random_state=27).reset_index(drop=True)


# Undersample the data
#data_raw = data_raw.groupby("age").apply(lambda x: x.sample(n=min(len(x)), random_state=27)).reset_index(drop=True)

table = generate_age_count_table(data_reduced)
print(table) """
# Out:
# ' #Undersample based on the demographic data\ndata_reduced = pd.DataFrame(columns=data_raw.columns)\nfor age in demographically_based_count["age"].unique():\n    \n    count_f = demographically_based_count[demographically_based_count["age"] == age]["count_f"].values[0].astype(int)\n    count_m = demographically_based_count[demographically_based_count["age"] == age]["count_m"].values[0].astype(int)\n    age_group_f = data_raw[(data_raw["age"] == age) & (data_raw["gender"] =="female_feminine")]\n    age_group_m = data_raw[(data_raw["age"] == age) & (data_raw["gender"] =="male_masculine")]\n    if len(age_group_f) > count_f:\n        age_group_f = age_group_f.sample(n=count_f, random_state=27)\n    if len(age_group_m) > count_m:\n        age_group_m = age_group_m.sample(n=count_m, random_state=27)\n    data_reduced = pd.concat([data_reduced, age_group_f, age_group_m], ignore_index=True)\ndata_reduced = data_reduced.sample(frac=1, random_state=27).reset_index(drop=True)\n\n\n# Undersample the data\n#data_raw = data_raw.groupby("age").apply(lambda x: x.sample(n=min(len(x)), random_state=27)).reset_index(drop=True)\n\ntable = generate_age_count_table(data_reduced)\nprint(table) '

# %%
#Legacy weighting of the data
def calculate_weights(data_clean): 
    weights_df = world_population.melt(
        id_vars="age", 
        value_vars=["F", "M"], 
        var_name="gender", 
        value_name="population_count"
    )

    # Map gender to full names
    weights_df["gender"] = weights_df["gender"].map(
        {"F": "female_feminine", "M": "male_masculine"}
    )

    # Add percentage columns back to the melted DataFrame
    weights_df["percentage"] = weights_df.apply(
        lambda row: row["population_count"] / weights_df["population_count"].sum(), axis=1
    )

    # STEP 2: Compute sample proportions from your dataset
    sample_counts = data_clean.groupby(["age","gender"]).size().reset_index(name="sample_count")
    total_sample_count = len(data_clean)
    sample_counts["sample_proportion"] = sample_counts["sample_count"] / total_sample_count

    # STEP 3: Merge and calculate weights
    weights_df = pd.merge(
        weights_df, 
        sample_counts, 
        on=["age", "gender"], 
        how="inner"
    )

    def adapted_sigmoid_scaling(w_raw):
        if w_raw < 1:
            return w_raw
        else:
            return np.log1p(w_raw)
    
    # Calculate sample weights
    weights_df["sample_weight"] = weights_df["percentage"] / weights_df["sample_proportion"]
    weights_df["log_sample_weight"] = weights_df["sample_weight"].apply(adapted_sigmoid_scaling)
    return weights_df


#Output to verify proportions and weights
weights_initial = calculate_weights(data_clean)
pd.set_option('display.float_format', lambda x: f'{x:0.4f}')
print("\n=== Age × Gender Weight Summary ===")
print(weights_initial[["age", "gender", "percentage", "sample_proportion", "sample_weight"]].sort_values(by=["age", "gender"]).reset_index(drop=True))
# Out:
# === Age × Gender Weight Summary ===
#        age           gender  percentage  sample_proportion  sample_weight
# 0  10.0000  female_feminine      0.0947             0.0255         3.7197
# 1  10.0000   male_masculine      0.1010             0.0876         1.1521
# 2  20.0000  female_feminine      0.0867             0.0856         1.0126
# 3  20.0000   male_masculine      0.0919             0.3220         0.2855
# 4  30.0000  female_feminine      0.0855             0.0399         2.1415
# 5  30.0000   male_masculine      0.0896             0.1752         0.5116
# 6  40.0000  female_feminine      0.0732             0.0256         2.8570
# 7  40.0000   male_masculine      0.0748             0.1027         0.7288
# 8  50.0000  female_feminine      0.0651             0.0248         2.6202
# 9  50.0000   male_masculine      0.0641             0.0547         1.1715
# 10 60.0000  female_feminine      0.0491             0.0123         3.9828
# 11 60.0000   male_masculine      0.0452             0.0284         1.5914
# 12 70.0000  female_feminine      0.0303             0.0034         8.8797
# 13 70.0000   male_masculine      0.0248             0.0104         2.3928
# 14 80.0000  female_feminine      0.0124             0.0003        39.7558
# 15 80.0000   male_masculine      0.0081             0.0014         5.9504
# 16 90.0000   male_masculine      0.0011             0.0002         6.1840

# %%
# Function to sample up to n_total rows with as balanced gender as possible
def balanced_sample_prefer_full_size(group, total_n=20000):
    female = group[group['gender'] == 'female_feminine']
    male = group[group['gender'] == 'male_masculine']
    
    n_female = len(female)
    n_male = len(male)

    # If both genders have enough to sample half-half
    if n_female >= total_n // 2 and n_male >= total_n // 2:
        female_sampled = resample(female, replace=False, n_samples=total_n // 2, random_state=27)
        male_sampled = resample(male, replace=False, n_samples=total_n // 2, random_state=27)
    else:
        # Use as many of the smaller gender as possible, fill remainder with the larger one
        if n_female < n_male:
            female_sampled = female  # use all
            male_sampled = resample(male, replace=False, n_samples=total_n - len(female_sampled), random_state=27)
        else:
            male_sampled = male  # use all
            female_sampled = resample(female, replace=False, n_samples=total_n - len(male_sampled), random_state=27)

    return pd.concat([female_sampled, male_sampled])

# Desired size per bin
TARGET_SIZE_PER_BIN = 20000

# Handle all bins except '30-49'
bins_excluding_30_49 = data_clean[data_clean['age_3_bins'] != '30-49']
sampled_bins = []

for bin_name, group in bins_excluding_30_49.groupby('age_3_bins'):
    sampled = balanced_sample_prefer_full_size(group, total_n=TARGET_SIZE_PER_BIN)
    sampled_bins.append(sampled)

# Handle 30-49 by splitting into age == 30 and age == 40
data_30 = data_clean[data_clean['age'] == 30]
data_40 = data_clean[data_clean['age'] == 40]

sampled_30 = balanced_sample_prefer_full_size(data_30, total_n=10000)
sampled_40 = balanced_sample_prefer_full_size(data_40, total_n=10000)

# Combine all
data_reduced = pd.concat(sampled_bins + [sampled_30, sampled_40], ignore_index=True)

# Verification
print("Age young/old distribution:")
print(data_reduced['age_young_old'].value_counts())

print("\nAge 3-bin distribution:")
print(data_reduced['age_3_bins'].value_counts())

print("\nGender distribution:")
print(data_reduced['gender'].value_counts())
# Out:
# Age young/old distribution:
# age_young_old
# young    30000
# old      30000
# Name: count, dtype: int64
#
# Age 3-bin distribution:
# age_3_bins
# 10-29    20000
# 50+      20000
# 30-49    20000
# Name: count, dtype: int64
#
# Gender distribution:
# gender
# male_masculine     33655
# female_feminine    26345
# Name: count, dtype: int64

# %%
# Data frames 
y= data_reduced[["gender", "age", "locale", "age_young_old", "age_3_bins"]]
X= data_reduced.drop(columns=["gender", "age", "accents", "locale","age_young_old", "age_3_bins"])


# Perform the train test split
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.15, random_state=27)
for train_full_index, test_index in sss.split(X,  y['age'].astype(str) + "-" + y['gender']):
    X_train_full = X.iloc[train_full_index]
    y_train_full = y.iloc[train_full_index]
    X_test = X.iloc[test_index]
    y_test = y.iloc[test_index]

# Further split the full training data set into training and validation
sss_train_val = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=27)
for train_index, val_index in sss_train_val.split(X_train_full, y_train_full['age'].astype(str) + "-" + y_train_full['gender']):
    X_train = X_train_full.iloc[train_index]
    y_train = y_train_full.iloc[train_index]
    X_val = X_train_full.iloc[val_index]
    y_val = y_train_full.iloc[val_index]

# Drop columns that are not needed
X_train = X_train.drop(columns=["path", "sentence", "client_id"])
X_test = X_test.drop(columns=["path", "sentence", "client_id"])
X_val = X_val.drop(columns=["path", "sentence", "client_id"])


# Df only for EDA
df_eda = X_train.copy()
df_eda['age'] = y_train["age"]
df_eda['gender'] = y_train['gender']
df_eda['age-gender'] = y_train["age"].astype(int).astype(str) + "-" + y_train["gender"].str[0]
df_eda['locale']=y_train['locale']
df_eda_cat = df_eda.select_dtypes(include=['object'])
df_eda_num = df_eda.select_dtypes(include=['number'])


y_train = y_train.copy()
y_val = y_val.copy()

label_encoder = LabelEncoder()
y_train["age_3_bins_encoded"] = label_encoder.fit_transform(y_train["age_3_bins"])
y_val["age_3_bins_encoded"] = label_encoder.transform(y_val["age_3_bins"])
y_train["age_young_old_encoded"] = label_encoder.fit_transform(y_train["age_young_old"])
y_val["age_young_old_encoded"] = label_encoder.transform(y_val["age_young_old"])



# Grid search to tune age prediction on true gender

X_train_male = X_train[y_train['gender'] == 'male_masculine']
y_train_male = y_train[y_train['gender'] == 'male_masculine']
X_val_male = X_val[y_val['gender'] == 'male_masculine']
y_val_male = y_val[y_val['gender'] == 'male_masculine']

X_train_female = X_train[y_train['gender'] == 'female_feminine']
y_train_female = y_train[y_train['gender'] == 'female_feminine']
X_val_female = X_val[y_val['gender'] == 'female_feminine']
y_val_female = y_val[y_val['gender'] == 'female_feminine']





print("X_train shape: ", X_train.shape)
print("X_val shape: ", X_val.shape)
print("X_test shape: ", X_test.shape)
# Out:
# X_train shape:  (40800, 88)
# X_val shape:  (10200, 88)
# X_test shape:  (9000, 88)

# %%
print(generate_age_count_table(y_train))
print(generate_age_count_table(y_val))
print(generate_age_count_table(y_test))
# Out:
# +------+------+------+-------+
# | Age  |  F   |  M   | Count |
# +------+------+------+-------+
# | 10.0 | 1586 | 1470 |  3056 |
# | 20.0 | 5214 | 5330 | 10544 |
# | 30.0 | 3400 | 3400 |  6800 |
# | 40.0 | 2971 | 3828 |  6799 |
# | 50.0 | 2881 | 5103 |  7984 |
# | 60.0 | 1430 | 2641 |  4071 |
# | 70.0 | 397  | 976  |  1373 |
# | 80.0 |  36  | 123  |  159  |
# | 90.0 |  0   |  14  |   14  |
# +------+------+------+-------+
# +------+------+------+-------+
# | Age  |  F   |  M   | Count |
# +------+------+------+-------+
# | 10.0 | 397  | 368  |  765  |
# | 20.0 | 1303 | 1332 |  2635 |
# | 30.0 | 850  | 850  |  1700 |
# | 40.0 | 743  | 957  |  1700 |
# | 50.0 | 720  | 1276 |  1996 |
# | 60.0 | 357  | 660  |  1017 |
# | 70.0 |  99  | 244  |  343  |
# | 80.0 |  9   |  31  |   40  |
# | 90.0 |  0   |  4   |   4   |
# +------+------+------+-------+
# +------+------+------+-------+
# | Age  |  F   |  M   | Count |
# +------+------+------+-------+
# | 10.0 | 350  | 324  |  674  |
# | 20.0 | 1150 | 1176 |  2326 |
# | 30.0 | 750  | 750  |  1500 |
# | 40.0 | 656  | 845  |  1501 |
# | 50.0 | 635  | 1126 |  1761 |
# | 60.0 | 316  | 582  |  898  |
# | 70.0 |  87  | 215  |  302  |
# | 80.0 |  8   |  27  |   35  |
# | 90.0 |  0   |  3   |   3   |
# +------+------+------+-------+

# %% [markdown]
# ## EDA

# %%
if FULL_RUN:
    df_eda.describe()

# %%
if FULL_RUN:
    df_eda.info()
    print(df_eda['gender'].value_counts())

# %%
# comparing the means of the features using groupbys

def table_grouped_by(df, group_by_col):
    grouped_by_y = df.groupby(group_by_col).mean().T
    table = PrettyTable()
    table.field_names = ["Feature"]+list(grouped_by_y.columns)
    for feature, values in zip(grouped_by_y.index, grouped_by_y.values):
        table.add_row([feature] + values.tolist())
    table.align = "r"
    table.align["Feature"] = "l"
    table.title = "Grouped by " + group_by_col.name
    print(table)

if FULL_RUN:    
    table_grouped_by(df_eda_num, df_eda['gender'])
    table_grouped_by(df_eda_num, df_eda['age'])
    table_grouped_by(df_eda_num, df_eda['age-gender'])
    table_grouped_by(df_eda_num, df_eda['locale'])

# %%
# Correlation Matrix (save to zoom in)

def generate_correlation_matrix(df):
    plt.figure(figsize=(50, 50))
    corr_matrix = df.corr()
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title('Correlation Matrix')
    plt.tight_layout()
    plt.show()

if FULL_RUN:    
    generate_correlation_matrix(df_eda_num)

# %%
# scatter plots
def scatter_plot(df, x_col, y_col):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x=x_col, y=y_col, hue=df[['age', 'gender']].apply(tuple, axis=1), alpha=0.8)
    plt.title(f'Scatter plot of {x_col} vs {y_col}')
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.show()

if FULL_RUN:
    # mfcc 
    # ....mfcc not multimodal
    scatter_plot(df_eda, 'mfcc_01_mean', 'mfcc_07_mean')
    scatter_plot(df_eda, 'mfcc_01_mean', 'spec_centroid_mean')
    # ....mfcc bimodal
    scatter_plot(df_eda, 'mfcc_02_mean', 'mfcc_04_mean')
    scatter_plot(df_eda, 'mfcc_02_mean', 'zcr_mean')


    # chroma differences in distances
    scatter_plot(df_eda, 'chroma_01_mean', 'chroma_02_mean')
    scatter_plot(df_eda, 'chroma_01_mean', 'chroma_05_mean')
    scatter_plot(df_eda, 'chroma_01_mean', 'chroma_11_mean')

    # spectral
    scatter_plot(df_eda, 'spec_centroid_mean', 'spec_bandwidth_mean')
    scatter_plot(df_eda, 'spec_centroid_mean', 'spec_contrast_band_1_mean')
    scatter_plot(df_eda, 'spec_centroid_mean', 'spec_contrast_band_4_mean')
    scatter_plot(df_eda, 'spec_centroid_mean', 'spec_contrast_band_7_mean')
    scatter_plot(df_eda, 'spec_centroid_mean', 'zcr_mean')

    # temporal
    scatter_plot(df_eda, 'zcr_mean', 'rmse_mean')

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.metrics import make_scorer, cohen_kappa_score, mean_absolute_error

# Define QWK scorer
qwk_scorer = make_scorer(cohen_kappa_score, greater_is_better=True, weights='quadratic')

# %%
# Log transformation
def use_log(data, scale_by_min=False):
    assert np.min(data) >= 0, 'data contains negative or zero values at log transform'
    transformed = np.log(data)
    return transformed

# Defining Transformers
scl = StandardScaler()
log = FunctionTransformer(func=use_log, validate=False, kw_args={'scale_by_min': True}, feature_names_out='one-to-one')

# Defining Models
pca = PCA(n_components=0.95) # try differnet n_components
lda = LinearDiscriminantAnalysis()

# Pipelines
pipeline_log = Pipeline(steps=[
    ('log', log),
    ('scaler', scl)
])

pipeline_num = Pipeline(steps=[
    ('scaler', scl)
])

# Column selection
preprocessing = ColumnTransformer([
('log', pipeline_log, col_to_log_transform),
], remainder=pipeline_num)

preprocessing_pca = Pipeline(steps=[
    ('preprocessing', preprocessing),
    ('pca', pca)
    ]
)
preprocessing_lda = Pipeline(steps=[
    ('preprocessing', preprocessing),
    ('lda', lda)
    ]
)

# %%
if FULL_RUN:
    # (EDA Step) checking results of PCA and LDA
    preprocessing.fit(X_train)
    preprocessing_pca.fit(X_train)
    preprocessing_lda.fit(X_train, y_train['age'])

# %%
if FULL_RUN:
    # Visualize PCA
    x_train_pca = preprocessing_pca.fit_transform(X_train)

    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=x_train_pca[:, 0], y=x_train_pca[:, 1], hue=y_train["age"], palette="hls", alpha=0.6)
    plt.title('Scatterplot of PC1 vs PC2')
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.legend(title='Age')
    plt.show()

# %%
# LDA
if FULL_RUN:
    lda = preprocessing_lda.named_steps['lda']

    coefficients = lda.coef_[0]
    imp_lda = pd.DataFrame(coefficients, index=X_train.columns, columns=['Coefficient']).sort_values(by='Coefficient', ascending=False)

    table = PrettyTable()
    table.field_names = ["Feature", "Coefficient"]
    for row in zip(imp_lda.index, imp_lda['Coefficient']):
        feature = str(row[0])
        coef = float(row[1])
        table.add_row([feature, coef])
    print(table)

# %%
if FULL_RUN:
    x_train_lda = preprocessing_lda.transform(X_train)
    print(x_train_lda.shape)

# %%
X_train.describe()
# Out:
#        mfcc_01_mean  mfcc_02_mean  mfcc_03_mean  mfcc_04_mean  mfcc_05_mean  \
# count    40800.0000    40800.0000    40800.0000    40800.0000    40800.0000
# mean      -427.1929      102.8427       -1.4630       21.8830        6.2724
# std         79.9555       27.5786       18.7181       15.0007       12.8823
# min       -724.8149       -2.4033      -98.1119      -51.6256      -64.8082
# 25%       -474.4866       85.4641      -13.0842       11.6541       -1.9345
# 50%       -417.1832      103.3287       -0.8655       21.5946        6.4602
# 75%       -373.6087      121.0646       10.8467       31.7246       14.7271
# max        -45.6894      221.4489       79.6414       87.3256       65.7912
#
#        mfcc_06_mean  mfcc_07_mean  mfcc_08_mean  mfcc_09_mean  mfcc_10_mean  \
# count    40800.0000    40800.0000    40800.0000    40800.0000    40800.0000
# mean         5.8307       -3.7421       -1.7639       -5.3818       -3.7507
# std         13.1234        9.9877        9.4937        7.9976        7.0559
# min        -51.1197      -59.7928      -50.5966      -46.1129      -36.3061
# 25%         -3.6091       -9.9949       -7.8077      -10.6847       -8.3341
# 50%          5.2394       -3.2078       -1.7510       -5.2208       -3.6579
# 75%         14.8662        2.9295        4.3798        0.0081        0.9335
# max         61.2546       40.7323       48.4032       32.0478       36.2443
#
#        ...  spec_contrast_band_4_std  spec_contrast_band_5_std  \
# count  ...                40800.0000                40800.0000
# mean   ...                    4.7144                    4.9413
# std    ...                    0.7917                    0.9722
# min    ...                    2.2338                    1.9921
# 25%    ...                    4.1556                    4.2675
# 50%    ...                    4.6262                    4.8057
# 75%    ...                    5.1883                    5.4714
# max    ...                   12.4167                   12.9128
#
#        spec_contrast_band_6_std  spec_contrast_band_7_std  spec_rolloff_mean  \
# count                40800.0000                40800.0000         40800.0000
# mean                     6.9539                    6.5783          4907.4252
# std                      2.0933                    2.9726          1822.9385
# min                      1.6168                    1.7437           434.4715
# 25%                      5.4897                    4.7822          3594.2960
# 50%                      6.7543                    5.8554          4582.6609
# 75%                      8.1877                    7.2377          5964.9836
# max                     20.6956                   26.3979         14939.0625
#
#        spec_rolloff_std   zcr_mean    zcr_std  rmse_mean   rmse_std
# count        40800.0000 40800.0000 40800.0000 40800.0000 40800.0000
# mean          2803.2953     0.0853     0.0723     0.0488     0.0569
# std            974.5622     0.0397     0.0293     0.0341     0.0333
# min            213.3003     0.0035     0.0065     0.0043     0.0009
# 25%           2043.9895     0.0570     0.0511     0.0240     0.0315
# 50%           2695.2531     0.0784     0.0690     0.0427     0.0538
# 75%           3448.4941     0.1060     0.0903     0.0656     0.0763
# max           6728.6470     0.4281     0.2844     0.3230     0.2939
#
# [8 rows x 88 columns]

# %%
preprocessed = preprocessing.fit_transform(X_train)
features = preprocessing.get_feature_names_out()

# %%
if FULL_RUN:
    df = pd.DataFrame(preprocessed, columns=features)
    df.head()
    histograms(df)

# %% [markdown]
# ## Fitting Models

# %%
def bin_age_young_old(age):
    if age < 40:
        return 'young'
    else:
        return 'old'
    
    
def bin_age_3_bins(age):
    if age < 30:
        return '10-29'
    elif age < 50:
        return '30-49'
    else:
        return '50+'
    

def bin_encoded_age_young_old(label):
    if label< 3:
        return 'young'
    else:
        return 'old'
    
def identity(x):
    return x

def encode_labels(y):
    unique = sorted(set(y))
    return pd.Series([unique.index(val) for val in y], index=y.index)


def apply_binning(data, func):
    if isinstance(data, pd.Series):
        return data.apply(func)
    elif isinstance(data, (list, np.ndarray)):
        return [func(x) for x in data]
    else:
        raise TypeError(f"Input must be a list, NumPy array, or Pandas Series. Got {type(data)} instead.")

# %%
def evaluate_models(y_true, y_pred_dict, figsize=(12, 8), expanded=True, label=None,binning=identity, numerical=True):
    """
    Function to evaluate multiple models and compare their performance
    
    Parameters:
    -----------
    y_true : array-like
        True labels
    y_pred_dict : dict
        Dictionary of model predictions where keys are model names and values are predicted labels
        Example: {'Model1': y_pred1, 'Model2': y_pred2}
    figsize : tuple, optional
        Figure size for the visualizations, default is (12, 8)
        
    Returns:
    --------
    metrics_df : pandas DataFrame
        DataFrame containing performance metrics for all models
    """

    y_true_transformed = apply_binning(y_true,binning)
    
    # Initialize a dictionary to store metrics
    metrics = {
        'Model': [],
        'Accuracy': [],
        'Precision': [],
        'Recall': [],
        'F1-score': [],
        'QWK': [],
        'MAE': []
    }
    
    if expanded:
        # Set up the plot for confusion matrices
        n_models = len(y_pred_dict)
        fig, axes = plt.subplots(1, n_models, figsize=figsize)
        if n_models == 1:
            axes = [axes]  # Convert to list for consistent indexing
    
    # Evaluate each model
    for i, (model_name, y_pred) in enumerate(y_pred_dict.items()):
        y_pred_transformed = apply_binning(y_pred,binning)
        # Print classification report
        print(f"\n===== {model_name}: {label} =====")
        print("Classification Report:")
        print(classification_report(y_true_transformed, y_pred_transformed))
        
        # Store metrics
        metrics['Model'].append(model_name)
        metrics['Accuracy'].append(accuracy_score(y_true_transformed, y_pred_transformed))
        
        unique_labels = np.unique(y_true_transformed)
        # Handle binary and multi-class cases for precision, recall, and f1
        if len(np.unique(y_true_transformed)) == 2:
            # Binary classification
            metrics['Precision'].append(precision_score(y_true_transformed, y_pred_transformed, average='binary', pos_label=unique_labels[1]))
            metrics['Recall'].append(recall_score(y_true_transformed, y_pred_transformed, average='binary', pos_label=unique_labels[1]))
            metrics['F1-score'].append(f1_score(y_true_transformed, y_pred_transformed, average='binary', pos_label=unique_labels[1]))
        else:
            # Multi-class classification
            metrics['Precision'].append(precision_score(y_true_transformed, y_pred_transformed, average='weighted', labels=unique_labels))
            metrics['Recall'].append(recall_score(y_true_transformed, y_pred_transformed, average='weighted', labels=unique_labels))
            metrics['F1-score'].append(f1_score(y_true_transformed, y_pred_transformed, average='weighted', labels=unique_labels))
            
            
        
        if numerical:
            # Calculate QWK squared and MAE
            qwk = cohen_kappa_score(y_true_transformed, y_pred_transformed, weights='quadratic')
            mae = mean_absolute_error(y_true_transformed, y_pred_transformed)
            metrics['QWK'].append(qwk)
            metrics['MAE'].append(mae)
            
            # Print QWK and MAE directly
            print(f"QWK: {qwk}")
            print(f"MAE: {mae}")
        else:
            # For non-numerical data, set QWK and MAE to NaN
            metrics['QWK'].append(np.nan)
            metrics['MAE'].append(np.nan)
        
        if expanded:
            # Plot confusion matrix
            
            cm = confusion_matrix(y_true_transformed, y_pred_transformed)
            labels = sorted(set(y_true_transformed).union(set(y_pred_transformed)))
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels, ax=axes[i])
            axes[i].set_title(f'Confusion Matrix - {model_name}')
            axes[i].set_xlabel('Predicted')
            axes[i].set_ylabel('True')
    
    if expanded:
        plt.tight_layout()
        plt.show()
    
    # Create metrics DataFrame
    metrics_df = pd.DataFrame(metrics)
    
    if expanded:
        # Plot metrics comparison excluding MAE
        plt.figure(figsize=(10, 6))
        metrics_df_plot = metrics_df.set_index('Model')
        metrics_df_plot[['Accuracy', 'Precision', 'Recall', 'F1-score', 'QWK']].plot(kind='bar', figsize=(10, 6))
        plt.title('Model Performance Comparison')
        plt.ylabel('Score')
        plt.ylim(0, 1)
        plt.legend(loc='lower right')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()
    
    return metrics_df

# %%
def fit_pipeline_predict_evaluate(model_class, model_name, X_train=X_train, y_train=y_train['age'], X_val=X_val, y_val=y_val['age'],PCA=False, LDA=False, binning=identity, numerical=True, multiclass=False):
    """
    Function to fit a pipeline, make predictions, and evaluate the model with optional weights.
    """
    # Create fresh instances of the model
    model = clone(model_class)
    
    # Build pipelines
    pipeline = make_pipeline(preprocessing, model)
        
    # Fit the model
    print(f"Fitting {model_name}...")
    pipeline.fit(X_train, y_train)
    
    if multiclass:
        # Predict on training set
        print(f"Predicting on training set...")
        prd_train = pipeline.predict(X_train)[:, 1]
        # Predict on validation set
        print(f"Predicting on validation set...")
        prd_val = pipeline.predict(X_val)[:, 1]
    else:
        # Predict on training set
        print(f"Predicting on training set...")
        prd_train = pipeline.predict(X_train)
        # Predict on validation set
        print(f"Predicting on validation set...")
        prd_val = pipeline.predict(X_val)

    # Same Pipeline for PCA and LDA if selected
    if PCA:
        model_pca = clone(model_class)
        pipeline_pca = make_pipeline(preprocessing_pca, model_pca)
        pipeline_pca.fit(X_train, y_train)
        prd_train_pca = pipeline_pca.predict(X_train)
        prd_val_pca = pipeline_pca.predict(X_val)

    if LDA:
        model_lda = clone(model_class)
        pipeline_lda = make_pipeline(preprocessing_lda, model_lda)
        pipeline_lda.fit(X_train, y_train)
        prd_train_lda = pipeline_lda.predict(X_train)
        prd_val_lda = pipeline_lda.predict(X_val)

    if PCA and LDA:
        evaluate_train = {
            f'{model_name}': prd_train,
            f'{model_name}_pca': prd_train_pca,
            f'{model_name}_lda': prd_train_lda,
        }
        evaluate_val = {
            f'{model_name}': prd_val,
            f'{model_name}_pca': prd_val_pca,
            f'{model_name}_lda': prd_val_lda,
        }
    elif PCA:
        evaluate_train = {
            f'{model_name}': prd_train,
            f'{model_name}_pca': prd_train_pca,
        }
        evaluate_val = {
            f'{model_name}': prd_val,
            f'{model_name}_pca': prd_val_pca,
        }
    elif LDA:
        evaluate_train = {
            f'{model_name}': prd_train,
            f'{model_name}_lda': prd_train_lda,
        }
        evaluate_val = {
            f'{model_name}': prd_val,
            f'{model_name}_lda': prd_val_lda,
        }
    else:
        evaluate_train = {
            f'{model_name}': prd_train,
        }
        evaluate_val = {
            f'{model_name}': prd_val,
        }
    
    if multiclass:
        y_train= y_train[:, 1]
        y_val= y_val[:, 1]

    # Evaluate on training predictions
    print(f"Evaluating {model_name} on training set...")
    evaluate_models(y_train, evaluate_train, (12, 8), False, "Training Set", binning=binning, numerical=numerical)

    # Evaluate on validation predictions
    print(f"Evaluating {model_name} on validation set...")
    return evaluate_models(y_val, evaluate_val, (12, 8), True, "Validation Set", binning=binning, numerical=numerical)

# %%
logistic_metrics=fit_pipeline_predict_evaluate(LogisticRegression(solver='lbfgs', max_iter=1000, C=190.0, random_state=27, class_weight="balanced"), "Logistic Regression", PCA=True, LDA=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 logistic_metrics=fit_pipeline_predict_evaluate(LogisticRegression(solver='lbfgs', max_iter=1000, C=190.0, random_state=27, class_weight="balanced"), "Logistic Regression", PCA=True, LDA=True)
#
# Cell In[64], line 12, in fit_pipeline_predict_evaluate(model_class, model_name, X_train, y_train, X_val, y_val, PCA, LDA, binning, numerical)
#       9 pipeline = make_pipeline(preprocessing, model)
#      11 # Fit the model
# ---> 12 pipeline.fit(X_train, y_train)
#      14 # Predict on training set
#      15 prd_train = pipeline.predict(X_train)
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\sklearn\pipeline.py:662, in Pipeline.fit(self, X, y, **params)
#     656     if self._final_estimator != "passthrough":
#     657         last_step_params = self._get_metadata_for_step(
#     658             step_idx=len(self) - 1,
#     659             step_params=routed_params[self.steps[-1][0]],
#     660             all_params=params,
#     661         )
# --> 662         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     664 return self
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\sklearn\linear_model\_logistic.py:1350, in LogisticRegression.fit(self, X, y, sample_weight)
#    1347 else:
#    1348     n_threads = 1
# -> 1350 fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1351     path_func(
#    1352         X,
#    1353         y,
#    1354         pos_class=class_,
#    1355         Cs=[C_],
#    1356         l1_ratio=self.l1_ratio,
#    1357         fit_intercept=self.fit_intercept,
#    1358         tol=self.tol,
#    1359         verbose=self.verbose,
#    1360         solver=solver,
#    1361         multi_class=multi_class,
#    1362         max_iter=self.max_iter,
#    1363         class_weight=self.class_weight,
#    1364         check_input=False,
#    1365         random_state=self.random_state,
#    1366         coef=warm_start_coef_,
#    1367         penalty=penalty,
#    1368         max_squared_sum=max_squared_sum,
#    1369         sample_weight=sample_weight,
#    1370         n_threads=n_threads,
#    1371     )
#    1372     for class_, warm_start_coef_ in zip(classes_, warm_start_coef)
#    1373 )
#    1375 fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#    1376 self.n_iter_ = np.asarray(n_iter_, dtype=np.int32)[:, 0]
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\sklearn\linear_model\_logistic.py:451, in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     447 l2_reg_strength = 1.0 / (C * sw_sum)
#     448 iprint = [-1, 50, 1, 100, 101][
#     449     np.searchsorted(np.array([0, 1, 2, 3]), verbose)
#     450 ]
# --> 451 opt_res = optimize.minimize(
#     452     func,
#     453     w0,
#     454     method="L-BFGS-B",
#     455     jac=True,
#     456     args=(X, target, sample_weight, l2_reg_strength, n_threads),
#     457     options={
#     458         "maxiter": max_iter,
#     459         "maxls": 50,  # default is 20
#     460         "iprint": iprint,
#     461         "gtol": tol,
#     462         "ftol": 64 * np.finfo(float).eps,
#     463     },
#     464 )
#     465 n_iter_i = _check_optimize_result(
#     466     solver,
#     467     opt_res,
#     468     max_iter,
#     469     extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
#     470 )
#     471 w0, loss = opt_res.x, opt_res.fun
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\scipy\optimize\_minimize.py:738, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     735     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     736                              **options)
#     737 elif meth == 'l-bfgs-b':
# --> 738     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     739                            callback=callback, **options)
#     740 elif meth == 'tnc':
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:441, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     433 _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr, pgtol, wa,
#     434                iwa, task, lsave, isave, dsave, maxls, ln_task)
#     436 if task[0] == 3:
#     437     # The minimization routine wants f and g at the current x.
#     438     # Note that interruptions due to maxfun are postponed
#     439     # until the completion of the current minimization iteration.
#     440     # Overwrite f and g:
# --> 441     f, g = func_and_grad(x)
#     442 elif task[0] == 1:
#     443     # new iteration
#     444     n_iterations += 1
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\scipy\optimize\_differentiable_functions.py:345, in ScalarFunction.fun_and_grad(self, x)
#     343     self._update_x(x)
#     344 self._update_fun()
# --> 345 self._update_grad()
#     346 return self.f, self.g
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\scipy\optimize\_differentiable_functions.py:307, in ScalarFunction._update_grad(self)
#     305 if self._orig_grad in FD_METHODS:
#     306     self._update_fun()
# --> 307 self.g = self._wrapped_grad(self.x, f0=self.f)
#     308 self.g_updated = True
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\scipy\optimize\_differentiable_functions.py:42, in _wrapper_grad.<locals>.wrapped(x, **kwds)
#      39 def wrapped(x, **kwds):
#      40     # kwds present to give function same signature as numdiff variant
#      41     ncalls[0] += 1
# ---> 42     return np.atleast_1d(grad(np.copy(x), *args))
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\scipy\optimize\_optimize.py:84, in MemoizeJac.derivative(self, x, *args)
#      83 def derivative(self, x, *args):
# ---> 84     self._compute_if_needed(x, *args)
#      85     return self.jac
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\scipy\optimize\_optimize.py:72, in MemoizeJac._compute_if_needed(self, x, *args)
#      71 def _compute_if_needed(self, x, *args):
# ---> 72     if not np.all(x == self.x) or self._value is None or self.jac is None:
#      73         self.x = np.asarray(x).copy()
#      74         fg = self.fun(x, *args)
#
# File c:\Users\danie\anaconda3\envs\tensorflow\Lib\site-packages\numpy\_core\fromnumeric.py:2606, in _all_dispatcher(a, axis, out, keepdims, where)
#    2498     """
#    2499     Test whether any array element along a given axis evaluates to True.
#    2500
#    (...)
#    2600
#    2601     """
#    2602     return _wrapreduction_any_all(a, np.logical_or, 'any', axis, out,
#    2603                                   keepdims=keepdims, where=where)
# -> 2606 def _all_dispatcher(a, axis=None, out=None, keepdims=None, *,
#    2607                     where=None):
#    2608     return (a, where, out)
#    2611 @array_function_dispatch(_all_dispatcher)
#    2612 def all(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
rand_forest_metrics=fit_pipeline_predict_evaluate(RandomForestClassifier(max_depth=20, n_estimators=400,
                                                                         max_features="sqrt", random_state=27, min_samples_leaf=2, min_samples_split=5)
, "Pre-Binned Random Forest Classifier", X_train=X_train, y_train=y_train["age_young_old_encoded"], X_val=X_val, y_val=y_val["age_young_old_encoded"], PCA=False, LDA=False,
                              binning=identity, numerical=False)
# Out:
# Fitting Pre-Binned Random Forest Classifier...
# Predicting on training set...
# Predicting on validation set...
# Evaluating Pre-Binned Random Forest Classifier on training set...
#
# ===== Pre-Binned Random Forest Classifier: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     20400
#            1       1.00      1.00      1.00     20400
#
#     accuracy                           1.00     40800
#    macro avg       1.00      1.00      1.00     40800
# weighted avg       1.00      1.00      1.00     40800
#
# Evaluating Pre-Binned Random Forest Classifier on validation set...
#
# ===== Pre-Binned Random Forest Classifier: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.73      5100
#            1       0.74      0.65      0.69      5100
#
#     accuracy                           0.71     10200
#    macro avg       0.72      0.71      0.71     10200
# weighted avg       0.72      0.71      0.71     10200

# %%
rand_forest_metrics=fit_pipeline_predict_evaluate(RandomForestClassifier(max_depth=20, n_estimators=400,
                                                                         max_features="sqrt", random_state=27, min_samples_leaf=2, min_samples_split=5)
, "Post-Binned Random Forest Classifier", X_train=X_train, y_train=y_train["age"], X_val=X_val, y_val=y_val["age"], PCA=False, LDA=False,
                              binning=bin_age_young_old, numerical=False)
# Out:
# Fitting Post-Binned Random Forest Classifier...
# Predicting on training set...
# Predicting on validation set...
# Evaluating Post-Binned Random Forest Classifier on training set...
#
# ===== Post-Binned Random Forest Classifier: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       1.00      1.00      1.00     20400
#        young       1.00      1.00      1.00     20400
#
#     accuracy                           1.00     40800
#    macro avg       1.00      1.00      1.00     40800
# weighted avg       1.00      1.00      1.00     40800
#
# Evaluating Post-Binned Random Forest Classifier on validation set...
#
# ===== Post-Binned Random Forest Classifier: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       0.76      0.56      0.64      5100
#        young       0.65      0.82      0.73      5100
#
#     accuracy                           0.69     10200
#    macro avg       0.70      0.69      0.68     10200
# weighted avg       0.70      0.69      0.68     10200

# %%
svc_metrics=fit_pipeline_predict_evaluate(LinearSVC(random_state=27, max_iter=1000), "SVC")
# Out:
# Evaluating SVC on training set...
#
# ===== SVC: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.32      0.62      0.42      4210
#         20.0       0.25      0.20      0.22      3842
#         30.0       0.25      0.34      0.29      3767
#         40.0       0.24      0.14      0.17      3185
#         50.0       0.27      0.22      0.24      2780
#         60.0       0.27      0.05      0.08      1988
#         70.0       0.12      0.00      0.00       854
#
#     accuracy                           0.28     20626
#    macro avg       0.25      0.22      0.20     20626
# weighted avg       0.26      0.28      0.25     20626
#
# Evaluating SVC on validation set...
#
# ===== SVC: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.32      0.62      0.42       903
#         20.0       0.23      0.18      0.20       824
#         30.0       0.25      0.33      0.28       808
#         40.0       0.20      0.11      0.14       683
#         50.0       0.24      0.18      0.21       595
#         60.0       0.25      0.04      0.08       426
#         70.0       0.00      0.00      0.00       182
#
#     accuracy                           0.27      4421
#    macro avg       0.21      0.21      0.19      4421
# weighted avg       0.24      0.27      0.23      4421

# %%
fit_pipeline_predict_evaluate(
LogisticAT(
    alpha=0.01,        # L2 regularization strength (lower = less regularization)
    max_iter=5000,    # More iterations for convergence on larger datasets
    verbose=1
), "Ordinal Logistic Regression", PCA=False, LDA=False, y_train=encode_labels(y_train["age"]), y_val=encode_labels(y_val["age"]),  binning=bin_encoded_age_young_old, numerical=False)
# Out:
# Fitting Ordinal Logistic Regression...
# Predicting on training set...
# Predicting on validation set...
# Evaluating Ordinal Logistic Regression on training set...
#
# ===== Ordinal Logistic Regression: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       0.62      0.65      0.64     20400
#        young       0.64      0.61      0.62     20400
#
#     accuracy                           0.63     40800
#    macro avg       0.63      0.63      0.63     40800
# weighted avg       0.63      0.63      0.63     40800
#
# Evaluating Ordinal Logistic Regression on validation set...
#
# ===== Ordinal Logistic Regression: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       0.62      0.65      0.63      5100
#        young       0.63      0.60      0.61      5100
#
#     accuracy                           0.62     10200
#    macro avg       0.62      0.62      0.62     10200
# weighted avg       0.62      0.62      0.62     10200
#                          Model  Accuracy  Precision  Recall  F1-score  QWK  \
# 0  Ordinal Logistic Regression    0.6212     0.6277  0.5957    0.6113  NaN
#
#    MAE
# 0  NaN

# %%
y_train_multi = np.column_stack((y_train["age"], y_train["age_young_old_encoded"]))
y_val_multi = np.column_stack((y_val["age"], y_val["age_young_old_encoded"]))

# Base model (intentionally large)
base_clf = RandomForestClassifier(
    n_estimators=500,          # Big forest
    max_depth=20,            
    min_samples_split=2,       # Allow aggressive splitting
    min_samples_leaf=1,        # Smallest possible leaves
    max_features='sqrt',       # Good default for classification
    bootstrap=False,            # Enable bagging
    class_weight=None,         # Let it learn naturally, change to 'balanced' if needed
    oob_score=False,           # Could enable if bootstrap is True
    n_jobs=-1,                 # Use all CPUs
    random_state=42,           # For reproducibility
    verbose=0
)

# Wrap as multi-output
multi_clf = MultiOutputClassifier(base_clf)

fit_pipeline_predict_evaluate( multi_clf, "Multi Output", PCA=False, LDA=False, y_train=y_train_multi, y_val=y_val_multi,  binning=identity, numerical=False, multiclass=True)
# Out:
# Fitting Multi Output...
# Predicting on training set...
# Predicting on validation set...
# Evaluating Multi Output on training set...
#
# ===== Multi Output: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     20400
#          1.0       1.00      1.00      1.00     20400
#
#     accuracy                           1.00     40800
#    macro avg       1.00      1.00      1.00     40800
# weighted avg       1.00      1.00      1.00     40800
#
# Evaluating Multi Output on validation set...
#
# ===== Multi Output: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.75      0.73      5100
#          1.0       0.73      0.68      0.71      5100
#
#     accuracy                           0.72     10200
#    macro avg       0.72      0.72      0.72     10200
# weighted avg       0.72      0.72      0.72     10200
#           Model  Accuracy  Precision  Recall  F1-score  QWK  MAE
# 0  Multi Output    0.7160     0.7318  0.6818    0.7059  NaN  NaN

# %%
fit_pipeline_predict_evaluate(MLPClassifier(activation='relu', alpha=0.01, batch_size=32, hidden_layer_sizes= (128, 64, 32), learning_rate_init=0.001,  max_iter=2000,
        random_state=27,
        learning_rate='adaptive',
        early_stopping=True,
        validation_fraction=0.1), "MLP Post-binned", X_train=X_train, y_train=y_train["age"], X_val=X_val, y_val=y_val["age"], PCA=False, LDA=False,
                              binning=bin_age_young_old, numerical=False)

fit_pipeline_predict_evaluate(MLPClassifier(activation='relu', alpha=0.01, batch_size=32, hidden_layer_sizes= (128, 64, 32), learning_rate_init=0.001,  max_iter=2000,
        random_state=27,
        learning_rate='adaptive',
        early_stopping=True,
        validation_fraction=0.1), "MLP Pre-Binned", X_train=X_train, y_train=y_train["age_young_old_encoded"], X_val=X_val, y_val=y_val["age_young_old_encoded"], PCA=False, LDA=False,
                              binning=identity, numerical=False)
# Out:
# Evaluating MLP on training set...
#
# ===== MLP: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       0.75      0.85      0.80     20400
#        young       0.82      0.72      0.77     20400
#
#     accuracy                           0.78     40800
#    macro avg       0.79      0.78      0.78     40800
# weighted avg       0.79      0.78      0.78     40800
#
# Evaluating MLP on validation set...
#
# ===== MLP: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       0.64      0.73      0.68      5100
#        young       0.69      0.59      0.63      5100
#
#     accuracy                           0.66     10200
#    macro avg       0.66      0.66      0.66     10200
# weighted avg       0.66      0.66      0.66     10200
# Evaluating MLP on training set...
#
# ===== MLP: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87     20400
#            1       0.89      0.85      0.87     20400
#
#     accuracy                           0.87     40800
#    macro avg       0.87      0.87      0.87     40800
# weighted avg       0.87      0.87      0.87     40800
#
# Evaluating MLP on validation set...
#
# ===== MLP: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.70      5100
#            1       0.70      0.65      0.67      5100
#
#     accuracy                           0.68     10200
#    macro avg       0.69      0.68      0.68     10200
# weighted avg       0.69      0.68      0.68     10200
#   Model  Accuracy  Precision  Recall  F1-score  QWK  MAE
# 0   MLP    0.6848     0.6981  0.6512    0.6738  NaN  NaN

# %%
kneighbors_metrics=fit_pipeline_predict_evaluate(KNeighborsClassifier(n_neighbors=10), "KNeighbors Classifier")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 kneighbors_metrics=fit_pipeline_predict_evaluate(KNeighborsClassifier(n_neighbors=10), "KNeighbors Classifier")
#
# NameError: name 'fit_pipeline_predict_evaluate' is not defined

# %%
# Define base model
model = KNeighborsClassifier()

# Create pipeline with preprocessing
pipeline = make_pipeline(preprocessing, model)

# Define grid of k values (number of neighbors)
param_grid = {
    'kneighborsclassifier__n_neighbors': list(range(1, 21))  # Try k = 1 to 20
}

# Set up GridSearchCV
search = GridSearchCV(
    pipeline,
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,
    verbose=2,
    n_jobs=-1,
    return_train_score=True
)

# Run search
search.fit(X_train, y_train['age'])

# Output best parameters
print("Best parameters:", search.best_params_)
print("Best score (accuracy):", search.best_score_)

# Detailed results in a DataFrame
results_df = pd.DataFrame(search.cv_results_).sort_values(by='mean_test_score', ascending=False)
print("\nTop 5 configurations:")
print(results_df[['param_kneighborsclassifier__n_neighbors', 'mean_test_score', 'std_test_score']].head())

print("\nBottom 5 configurations:")
print(results_df[['param_kneighborsclassifier__n_neighbors', 'mean_test_score', 'std_test_score']].tail())
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best parameters: {'kneighborsclassifier__n_neighbors': 14}
# Best score (accuracy): 0.22661920624950546
#
# Top 5 configurations:
#     param_kneighborsclassifier__n_neighbors  mean_test_score  std_test_score
# 13                                       14           0.2266          0.0026
# 16                                       17           0.2250          0.0060
# 14                                       15           0.2248          0.0049
# 15                                       16           0.2241          0.0048
# 17                                       18           0.2237          0.0051
#
# Bottom 5 configurations:
#    param_kneighborsclassifier__n_neighbors  mean_test_score  std_test_score
# 9                                       10           0.2154          0.0017
# 7                                        8           0.2152          0.0029
# 2                                        3           0.2117          0.0020
# 3                                        4           0.2111          0.0018
# 0                                        1           0.1919          0.0029

# %%
#mlp_metrics=fit_pipeline_predict_evaluate(MLPClassifier(hidden_layer_sizes=(10,10), max_iter=1000, random_state=27, batch_size=32, learning_rate='adaptive', learning_rate_init=0.0003), "MLP Classifier")

""" mlp_metrics=fit_pipeline_predict_evaluate(MLPClassifier(hidden_layer_sizes=(64, 64),
              max_iter=1000,
              random_state=27,
              batch_size=32,
              learning_rate='adaptive',
              learning_rate_init=0.001,
              alpha=0.0001),
 "MLP Classifier") """

""" mlp_metrics=fit_pipeline_predict_evaluate(MLPClassifier(hidden_layer_sizes=(128, 64),  
              max_iter=1000,
              random_state=27,
              batch_size=64,  
              learning_rate='adaptive',
              learning_rate_init=0.0005,  
              alpha=0.001, 
              early_stopping=True,
              validation_fraction=0.1),
 "MLP Classifier") """


mlp_metrics=fit_pipeline_predict_evaluate(MLPClassifier(hidden_layer_sizes=(128, 64, 32),
              max_iter=2000,
              random_state=27,
              batch_size=32,
              learning_rate='adaptive',
              learning_rate_init=0.0005,
              alpha=0.001,
              early_stopping=True,
              validation_fraction=0.1)
, "MLP Classifier")

""" mlp_metrics=fit_pipeline_predict_evaluate(MLPClassifier(hidden_layer_sizes=(128, 64, 32),
              alpha=0.001,
              learning_rate_init=0.0005,
              max_iter=2000,
              batch_size=32,
              early_stopping=True,
              validation_fraction=0.1,
              random_state=27,
              solver='adam')
, "MLP Classifier") """
# Out:
# Evaluating MLP Classifier on training set...
#
# ===== MLP Classifier: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.43      0.67      0.52      4210
#         20.0       0.41      0.32      0.36      3842
#         30.0       0.37      0.41      0.39      3767
#         40.0       0.42      0.32      0.36      3185
#         50.0       0.38      0.41      0.40      2780
#         60.0       0.44      0.24      0.31      1988
#         70.0       0.53      0.30      0.38       854
#
#     accuracy                           0.41     20626
#    macro avg       0.43      0.38      0.39     20626
# weighted avg       0.41      0.41      0.40     20626
#
# Evaluating MLP Classifier on validation set...
#
# ===== MLP Classifier: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.35      0.57      0.44       903
#         20.0       0.22      0.17      0.19       824
#         30.0       0.26      0.27      0.27       808
#         40.0       0.24      0.20      0.22       683
#         50.0       0.25      0.26      0.26       595
#         60.0       0.28      0.15      0.20       426
#         70.0       0.28      0.12      0.16       182
#
#     accuracy                           0.28      4421
#    macro avg       0.27      0.25      0.25      4421
# weighted avg       0.27      0.28      0.27      4421
# ' mlp_metrics=fit_pipeline_predict_evaluate(MLPClassifier(hidden_layer_sizes=(128, 64, 32),\n              alpha=0.001,\n              learning_rate_init=0.0005,\n              max_iter=2000,\n              batch_size=32,\n              early_stopping=True,\n              validation_fraction=0.1,\n              random_state=27,\n              solver=\'adam\')\n, "MLP Classifier") '

# %%
def optimize_mlp_with_gridsearch(param_grid=None, PCA=False, LDA=False):
    if param_grid is None:
        # Updated parameter grid
        param_grid = {
            'mlp__hidden_layer_sizes': [
                (128, 64), 
                (128, 64, 32), 
                (256, 128, 64, 32)
            ],
            'mlp__activation': ['relu', 'tanh', 'logistic'],
            'mlp__alpha': [0.0001, 0.001, 0.01],
            'mlp__learning_rate_init': [0.001, 0.0005, 0.0001],
            'mlp__batch_size': [32, 64],
        }

    mlp = MLPClassifier(
        max_iter=2000,
        random_state=27,
        learning_rate='adaptive',
        early_stopping=True,
        validation_fraction=0.1
    )

    base_pipeline = Pipeline([
        ('preprocessing', preprocessing),
        ('mlp', mlp)
    ])

    grid_search = GridSearchCV(
        base_pipeline,
        param_grid=param_grid,
        cv=3,
        scoring='accuracy',
        verbose=2,
        n_jobs=-1
    )

    grid_search.fit(X_train, y_train['age'])

    print(f"Best Parameters: {grid_search.best_params_}")
    best_model = grid_search.best_estimator_

    prd_train = best_model.predict(X_train)
    prd_val = best_model.predict(X_val)

    if PCA:
        model_pca = MLPClassifier(
            **grid_search.best_params_['mlp'], 
            max_iter=2000, 
            random_state=27, 
            learning_rate='adaptive', 
            early_stopping=True, 
            validation_fraction=0.1
        )
        pipeline_pca = make_pipeline(preprocessing_pca, model_pca)
        pipeline_pca.fit(X_train, y_train['age'])
        prd_train_pca = pipeline_pca.predict(X_train)
        prd_val_pca = pipeline_pca.predict(X_val)

    if LDA:
        model_lda = MLPClassifier(
            **grid_search.best_params_['mlp'], 
            max_iter=2000, 
            random_state=27, 
            learning_rate='adaptive', 
            early_stopping=True, 
            validation_fraction=0.1
        )
        pipeline_lda = make_pipeline(preprocessing_lda, model_lda)
        pipeline_lda.fit(X_train, y_train['age'])
        prd_train_lda = pipeline_lda.predict(X_train)
        prd_val_lda = pipeline_lda.predict(X_val)

    # Build evaluation dicts
    evaluate_train = {'MLP': prd_train}
    evaluate_val = {'MLP': prd_val}

    if PCA:
        evaluate_train['MLP_PCA'] = prd_train_pca
        evaluate_val['MLP_PCA'] = prd_val_pca
    if LDA:
        evaluate_train['MLP_LDA'] = prd_train_lda
        evaluate_val['MLP_LDA'] = prd_val_lda

    print("Evaluating MLP on training set...")
    evaluate_models(y_train['age'], evaluate_train, (12, 8), False, "Training Set")

    print("Evaluating MLP on validation set...")
    return evaluate_models(y_val['age'], evaluate_val, (12, 8), True, "Validation Set")

# %%
def optimize_rf_with_gridsearch(param_grid=None, PCA=False, LDA=False):
    
    if param_grid is None:
        param_grid = {
            'rf__n_estimators': [100, 150, 200],
            'rf__max_depth': [None, 10, 20, 30],
            'rf__min_samples_split': [2, 5, 10],
            'rf__min_samples_leaf': [1, 2, 4],
            'rf__bootstrap': [True, False]
        }

    rf = RandomForestClassifier(random_state=27)

    base_pipeline = Pipeline([
        ('preprocessing', preprocessing),
        ('rf', rf)
    ])

    grid_search = GridSearchCV(
        base_pipeline,
        param_grid=param_grid,
        cv=3,
        scoring='accuracy',
        verbose=2,
        n_jobs=-1
    )

    grid_search.fit(X_train, y_train['age'])

    print(f"Best Parameters: {grid_search.best_params_}")
    best_model = grid_search.best_estimator_

    prd_train = best_model.predict(X_train)
    prd_val = best_model.predict(X_val)

    # PCA or LDA variants
    if PCA:
        model_pca = RandomForestClassifier(**grid_search.best_params_['rf'], random_state=27)
        pipeline_pca = make_pipeline(preprocessing_pca, model_pca)
        pipeline_pca.fit(X_train, y_train['age'])
        prd_train_pca = pipeline_pca.predict(X_train)
        prd_val_pca = pipeline_pca.predict(X_val)

    if LDA:
        model_lda = RandomForestClassifier(**grid_search.best_params_['rf'], random_state=27)
        pipeline_lda = make_pipeline(preprocessing_lda, model_lda)
        pipeline_lda.fit(X_train, y_train['age'])
        prd_train_lda = pipeline_lda.predict(X_train)
        prd_val_lda = pipeline_lda.predict(X_val)

    evaluate_train = {'RandomForest': prd_train}
    evaluate_val = {'RandomForest': prd_val}

    if PCA:
        evaluate_train['RandomForest_PCA'] = prd_train_pca
        evaluate_val['RandomForest_PCA'] = prd_val_pca
    if LDA:
        evaluate_train['RandomForest_LDA'] = prd_train_lda
        evaluate_val['RandomForest_LDA'] = prd_val_lda

    print("Evaluating Random Forest on training set...")
    evaluate_models(y_train['age'], evaluate_train, (12, 8), False, "Training Set")

    print("Evaluating Random Forest on validation set...")
    return evaluate_models(y_val['age'], evaluate_val, (12, 8), True, "Validation Set")

# %%
# Define base model
model = HistGradientBoostingClassifier(random_state=27)

# Create the pipeline
pipeline = make_pipeline(preprocessing, model)

# Define hyperparameter search space
param_distributions = {
    'histgradientboostingclassifier__max_iter': [300, 500, 700],
    'histgradientboostingclassifier__learning_rate': [0.01, 0.05, 0.1],
    'histgradientboostingclassifier__max_depth': [4, 6, 8, 10],
    'histgradientboostingclassifier__l2_regularization': [0.0, 0.2, 0.5, 1.0],
    'histgradientboostingclassifier__min_samples_leaf': [20, 50, 100]
}

# Set up RandomizedSearchCV
search = RandomizedSearchCV(
    pipeline,
    param_distributions=param_distributions,
    n_iter=20,
    scoring='accuracy',
    cv=3,
    verbose=2,
    random_state=27,
    n_jobs=-1
)

# Run search
search.fit(X_train, y_train['age'])

# Output best parameters
print("Best parameters:", search.best_params_)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best parameters: {'histgradientboostingclassifier__min_samples_leaf': 20, 'histgradientboostingclassifier__max_iter': 700, 'histgradientboostingclassifier__max_depth': 6, 'histgradientboostingclassifier__learning_rate': 0.05, 'histgradientboostingclassifier__l2_regularization': 0.5}

# %%
#gradient_boosting_metrics=fit_pipeline_predict_evaluate(HistGradientBoostingClassifier(max_iter=100, random_state=27), "Gradient Boosting Classifier")

gradient_boosting_metrics=fit_pipeline_predict_evaluate(HistGradientBoostingClassifier(
    min_samples_leaf=20,      # Minimum samples per leaf
    max_iter=700,            # Number of boosting rounds
    learning_rate=0.05,      # Learning rate
    max_depth=6,             # Tree depth
    l2_regularization=0.5,   # L2 reg
    random_state=27
), "Gradient Boosting Classifier")
# Out:
# Evaluating Gradient Boosting Classifier on training set...
#
# ===== Gradient Boosting Classifier: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.88      0.92      0.90      4210
#         20.0       0.90      0.90      0.90      3842
#         30.0       0.87      0.90      0.88      3767
#         40.0       0.89      0.90      0.90      3185
#         50.0       0.93      0.89      0.91      2780
#         60.0       0.95      0.88      0.92      1988
#         70.0       0.99      0.91      0.95       854
#
#     accuracy                           0.90     20626
#    macro avg       0.92      0.90      0.91     20626
# weighted avg       0.90      0.90      0.90     20626
#
# Evaluating Gradient Boosting Classifier on validation set...
#
# ===== Gradient Boosting Classifier: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.39      0.52      0.45       903
#         20.0       0.26      0.29      0.27       824
#         30.0       0.29      0.34      0.32       808
#         40.0       0.28      0.27      0.28       683
#         50.0       0.34      0.27      0.30       595
#         60.0       0.40      0.17      0.24       426
#         70.0       0.61      0.11      0.19       182
#
#     accuracy                           0.32      4421
#    macro avg       0.37      0.28      0.29      4421
# weighted avg       0.33      0.32      0.31      4421

# %%
# Compare selected metrics in one graph
def compare_selected_metrics(logistic_metrics, rand_forest_metrics, svc_metrics, kneighbors_metrics, mlp_metrics, gradient_boosting_metrics):
    # Combine all metrics into a single DataFrame
    combined_metrics = pd.concat([logistic_metrics.set_index('Model'), 
                                   rand_forest_metrics.set_index('Model'), 
                                   svc_metrics.set_index('Model'), 
                                   kneighbors_metrics.set_index('Model'), 
                                   mlp_metrics.set_index('Model'), 
                                   gradient_boosting_metrics.set_index('Model')], axis=0)
    
    # Drop models that end with "pca" or "lda"
    combined_metrics = combined_metrics[~combined_metrics.index.str.endswith(('pca', 'lda'))]
    
    # Select only the desired metrics
    selected_metrics = combined_metrics[['Accuracy', 'Precision', 'Recall', 'F1-score', 'QWK']]
    
    # Plot the selected metrics
    plt.figure(figsize=(12, 8))
    selected_metrics.plot(kind='bar', figsize=(12, 8))
    plt.title('Comparison of Model Performance Metrics (Excluding MAE)')
    plt.ylabel('Score')
    plt.ylim(0, 1)
    plt.legend(loc='lower right')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

compare_selected_metrics(logistic_metrics, rand_forest_metrics, svc_metrics, kneighbors_metrics, mlp_metrics, gradient_boosting_metrics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 27
#      24     plt.grid(axis='y', linestyle='--', alpha=0.7)
#      25     plt.show()
# ---> 27 compare_selected_metrics(logistic_metrics, rand_forest_metrics, svc_metrics, kneighbors_metrics, mlp_metrics, gradient_boosting_metrics)
#
# NameError: name 'rand_forest_metrics' is not defined

# %% [markdown]
# ## Two Stage Models

# %%
def evaluate_layered_model(predicted_age_val, y_val_age, y_val_gender, age_model_name, label=None, numerical=True, binning=identity):
    for gender in ['female_feminine','male_masculine',  'total']:
        if gender == 'total':
            gender_mask = y_val_gender.notnull()
        else:
            gender_mask = y_val_gender == gender

        y_true_gender = apply_binning(y_val_age[gender_mask],binning)
        y_pred_gender = apply_binning([predicted_age_val[i] for i in range(len(predicted_age_val)) if gender_mask.iloc[i]], binning)

        print(f"\n{age_model_name} - Prediction Report on Gender {gender}: {label}")
        print(classification_report(y_true_gender, y_pred_gender))

        if numerical:
            # Calculate QWK and MAE
            qwk = cohen_kappa_score(y_true_gender, y_pred_gender, weights='quadratic')
            mae = mean_absolute_error(y_true_gender, y_pred_gender)
            print(f"QWK (Quadratic Weighted Kappa): {qwk:.4f}")
            print(f"MAE (Mean Absolute Error): {mae:.4f}")

     
        # Plot confusion matrix
        cm_age_gender = confusion_matrix(y_true_gender, y_pred_gender)
        labels = sorted(set(y_true_gender).union(set(y_pred_gender)))
        sns.heatmap(cm_age_gender, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
        plt.title(f'Confusion Matrix {age_model_name} - Prediction on Gender {gender}: {label}')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.show()

# %%
def fit_predict_gender_age_pipeline(gender_model_class, age_model_class_male, age_model_class_female, gender_model_name="GenderModel", age_model_name="AgeModel"):
    """
    Function to fit a gender classification pipeline and then train separate age prediction models by gender.
    Evaluates and visualizes the performance at each stage.
    """
    # Clone models
    gender_model = clone(gender_model_class)
    gender_model_pca = clone(gender_model_class)
    gender_model_lda = clone(gender_model_class)

    # Build gender prediction pipelines
    pipe_gender = make_pipeline(preprocessing, gender_model)
    pipe_gender_pca = make_pipeline(preprocessing_pca, gender_model_pca)
    pipe_gender_lda = make_pipeline(preprocessing_lda, gender_model_lda)

    # Fit gender classifiers
    pipe_gender.fit(X_train, y_train['gender'])
    pipe_gender_pca.fit(X_train, y_train['gender'])
    pipe_gender_lda.fit(X_train, y_train['gender'])

    # Evaluate gender predictions
    for name, pipe in zip(['Default', 'PCA', 'LDA'], [pipe_gender, pipe_gender_pca, pipe_gender_lda]):
        for split_name, X, y in [('Training', X_train, y_train), ('Validation', X_val, y_val)]:
            preds = pipe.predict(X)
            print(f"\n{name} Gender Model - {split_name} Set:")
            print(classification_report(y['gender'], preds))

            if split_name == 'Validation':
                cm = confusion_matrix(y['gender'], preds)
                sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
                plt.title(f'Confusion Matrix - Gender ({name}, {split_name} Set)')
                plt.xlabel('Predicted')
                plt.ylabel('True')
                plt.show()

    # Use the default pipeline for gender predictions
    predicted_gender_val = pipe_gender.predict(X_val)

    # Train separate age models on true gender-labeled training data
    X_train_male = X_train[y_train['gender'] == 'male_masculine']
    y_train_male = y_train.loc[y_train['gender'] == 'male_masculine', 'age']
    X_train_female = X_train[y_train['gender'] == 'female_feminine']
    y_train_female = y_train.loc[y_train['gender'] == 'female_feminine', 'age']

    pipe_age_male = make_pipeline(preprocessing, clone(age_model_class_male))
    pipe_age_female = make_pipeline(preprocessing, clone(age_model_class_female))

    pipe_age_male.fit(X_train_male, y_train_male)
    pipe_age_female.fit(X_train_female, y_train_female)

    # Predict age on validation set using predicted gender
    predicted_age_val = []
    for i, gender in enumerate(predicted_gender_val):
        x_instance = X_val.iloc[[i]]  # preserve column names
        if gender == 'male_masculine':
            predicted_age_val.append(pipe_age_male.predict(x_instance)[0])
        else:
            predicted_age_val.append(pipe_age_female.predict(x_instance)[0])
    
    evaluate_layered_model(predicted_age_val, y_val, age_model_name, "Validation Set")

# %%
def fit_predict_gender_age_pipeline_with_joint_comparison(
    gender_model_class,
    age_model_class_female,
    age_model_class_male,
    gender_model_name="GenderModel",
    age_model_name="AgeModel",
    X_train=X_train, y_train_age=y_train["age"], y_train_gender=y_train["gender"],
    X_val=X_val, y_val_age=y_val["age"], y_val_gender=y_val["gender"], 
    numerical=True, binning=identity, multiclass=False):

 
    
    # ====== Fit gender model ======
    pipe_gender = make_pipeline(clone(preprocessing),clone(gender_model_class))
    print(f"\nFitting {gender_model_name} on training set")
    pipe_gender.fit(X_train, y_train_gender)

    print(f"\nPredicting {gender_model_name} on training set")
    predicted_gender_train=pipe_gender.predict(X_train)
    print(f"\nPredicting {gender_model_name} on validation set")
    predicted_gender_val = pipe_gender.predict(X_val)
    for split_name, preds, y in [('Training', predicted_gender_train, y_train_gender), ('Validation', predicted_gender_val, y_val_gender)]:
            print(f"\n{gender_model_name} Gender Model - {split_name} Set:")
            print(classification_report(y, preds))

            if split_name == 'Validation':
                cm = confusion_matrix(y, preds)
                sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
                plt.title(f'Confusion Matrix - Gender ({gender_model_name}, {split_name} Set)')
                plt.xlabel('Predicted')
                plt.ylabel('True')
                plt.show()

    # ====== Train age models ======
    # Split train set by gender
    X_train_male = X_train[y_train_gender == 'male_masculine']
    y_train_male = y_train_age[y_train_gender == 'male_masculine']
    X_train_female = X_train[y_train_gender== 'female_feminine']
    y_train_female = y_train_age[y_train_gender == 'female_feminine']

    # Fit individual age models
    
    pipe_age_male = make_pipeline(clone(preprocessing), clone(age_model_class_male))
    pipe_age_female = make_pipeline(clone(preprocessing), clone(age_model_class_female))

    print(f"\nFitting {age_model_name} on Gender Female")
    pipe_age_female.fit(X_train_female, y_train_female)

    print(f"\nFitting {age_model_name} on Gender Male")
    pipe_age_male.fit(X_train_male, y_train_male)

    
    # ====== Age predictions ======
    predicted_age_true_gender = []
    predicted_age_pred_gender = []
    for i in tqdm(range(len(X_val)), desc=f"Predicting {age_model_name} on validation set"):
        x_instance = X_val.iloc[[i]]

        # TRUE gender routing
        true_gender = y_val_gender.iloc[i]
        model_true = pipe_age_male if true_gender == 'male_masculine' else pipe_age_female
        predicted_age_true_gender.append(model_true.predict(x_instance)[0])

        # PREDICTED gender routing
        pred_gender = predicted_gender_val[i]
        model_pred = pipe_age_male if pred_gender == 'male_masculine' else pipe_age_female
        predicted_age_pred_gender.append(model_pred.predict(x_instance)[0])


    if multiclass:
        y_val_age = y_val_age[:, 1]
        predicted_age_true_gender = np.array(predicted_age_true_gender)[:, 1]
        predicted_age_pred_gender = np.array(predicted_age_pred_gender)[:, 1]


    # ====== Evaluation ======

    evaluate_layered_model(predicted_age_true_gender, y_val_age,y_val_gender, age_model_name, "Routed by True Gender", numerical=numerical, binning=binning)
    evaluate_layered_model(predicted_age_pred_gender, y_val_age,y_val_gender, age_model_name, "Routed by Predicted Gender", numerical=numerical, binning=binning)

    # ====== Routing error cost ======
    acc_true = accuracy_score(apply_binning(y_val_age,binning), apply_binning(predicted_age_true_gender,binning))
    acc_pred = accuracy_score(apply_binning(y_val_age,binning), apply_binning(predicted_age_pred_gender,binning))
    routing_cost = acc_true - acc_pred
    print(f"\n Routing Error Cost (Accuracy Loss from using predicted gender): {routing_cost:.4f}")

    return {
        "acc_true_gender": acc_true,
        "acc_pred_gender": acc_pred,
        "routing_error_cost": routing_cost
    }

# %%
def optimize_mlp_for_gender(
    X_train, y_train, X_val, y_val,
    preprocessing,
    param_grid=None
):
    if param_grid is None:
        param_grid = {
            'mlp__hidden_layer_sizes': [(128, 64, 32), (256, 128, 64, 32)],
            'mlp__activation': ['relu', 'tanh'],
            'mlp__alpha': [0.0001, 0.001, 0.01],
            'mlp__learning_rate_init': [0.001, 0.0005, 0.0001],
            'mlp__batch_size': [32, 64],
        }

    mlp = MLPClassifier(
        max_iter=2000,
        random_state=27,
        learning_rate='adaptive',
        early_stopping=True,
        validation_fraction=0.1
    )

    pipeline = Pipeline([
        ('preprocessing', preprocessing),
        ('mlp', mlp)
    ])

    # Create stratification labels from age and gender
    strat_labels = y_train['age'].astype(str) + "-" + y_train['gender']
    # Define stratified k-fold cross-validation on full training set
    stratified_cv= StratifiedKFold(n_splits=3, shuffle=True, random_state=27).split(X_train, strat_labels)

    grid_search = GridSearchCV(
        pipeline,
        param_grid=param_grid,
        cv=stratified_cv,
        scoring='accuracy',
        verbose=2,
        n_jobs=-1
    )

    print("Starting grid search for MLP...")
    grid_search.fit(X_train, y_train["age"])

    print(f"\nBest Parameters: {grid_search.best_params_}")
    best_model = grid_search.best_estimator_

    # Detailed results as DataFrame
    results_df = pd.DataFrame(grid_search.cv_results_)
    results_df_sorted = results_df.sort_values(by='mean_test_score', ascending=False)
    print("\nTop 5 configurations:")
    display_cols = [col for col in results_df.columns if col.startswith("param_")]
    display_cols += ['mean_test_score', 'std_test_score']
    print(results_df_sorted[display_cols].head())

    # Predictions
    prd_train = best_model.predict(X_train)
    prd_val = best_model.predict(X_val)

    # Evaluation
    evaluate_train = {'MLP': prd_train}
    evaluate_val = {'MLP': prd_val}

    print("\nEvaluating MLP on training set...")
    evaluate_models(y_train["age"], evaluate_train, (12, 8), False, "Training Set")

    print("\nEvaluating MLP on validation set...")
    evaluate_models(y_val["age"], evaluate_val, (12, 8), True, "Validation Set")

    return best_model, evaluate_train, evaluate_val, results_df_sorted

# %%
best_male_model, train_eval_male, val_eval_male, results_male = optimize_mlp_for_gender(
    X_train_male, y_train_male, X_val_male, y_val_male, preprocessing=preprocessing
)
# Out:
# Starting grid search for MLP...
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   8.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   8.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   9.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  13.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  15.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  17.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  19.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  19.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  15.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  16.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  11.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  22.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  17.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  16.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  17.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  24.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  33.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  39.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  38.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  41.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   7.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  13.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   8.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  46.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   9.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  59.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  10.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.3min
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   7.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  11.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  10.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  14.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  12.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  14.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  11.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  11.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  50.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.1min
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  12.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.6min
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  18.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  21.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  16.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  33.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  32.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  19.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  25.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  26.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  42.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  40.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  14.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  16.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  11.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  29.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  13.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  16.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  17.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  16.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  22.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  18.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  12.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  47.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  19.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  17.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  25.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  31.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  19.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  24.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  29.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  34.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  49.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  50.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  51.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   6.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   7.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.2min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   9.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  48.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  52.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.3min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   6.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  10.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   8.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  10.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  12.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  11.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=   9.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  12.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  14.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  12.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=   8.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=   9.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  15.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  18.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.5min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  20.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.1min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  17.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  34.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  35.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  35.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  31.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  28.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  28.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  12.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   8.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  13.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  10.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  17.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  25.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  24.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  13.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  17.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  14.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  17.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  21.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  23.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  16.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  55.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  14.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  30.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  24.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  45.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  45.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  53.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.2min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  23.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  55.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.3min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  14.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.4min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  10.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  43.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   9.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   9.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.4min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  10.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  10.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  11.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  52.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=   8.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  11.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  19.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  15.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  21.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  15.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  13.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  14.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  17.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  23.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  21.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  23.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  28.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  32.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  36.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   8.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  11.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  30.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   7.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  35.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  20.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  12.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  14.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  16.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  37.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  15.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  14.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  18.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  12.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  48.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  19.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  15.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  15.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  24.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  22.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  17.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  26.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  32.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  44.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.0min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  50.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   6.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.1min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  52.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   9.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  14.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.1min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   7.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  13.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  14.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  15.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  11.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=   7.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  19.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  17.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=   8.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  10.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  12.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  16.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  12.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  12.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  20.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  31.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  37.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  41.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  34.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  36.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   8.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   9.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  46.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  14.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  21.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.1min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  15.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  15.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  49.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  18.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  17.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  23.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  20.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  19.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  15.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  17.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.2min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  15.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  23.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  24.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  27.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  32.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  36.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  48.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  55.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  14.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  46.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   5.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   8.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.1min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   7.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  12.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  11.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.0min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  14.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=   6.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  12.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  18.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=   8.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  18.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.0min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  11.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  15.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  10.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=   8.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  10.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  18.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  26.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.6min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  34.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  37.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  34.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  12.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  33.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  16.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  43.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   8.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  39.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  11.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  22.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.1min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  14.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  23.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  14.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  15.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  17.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  20.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  13.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  14.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  16.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  15.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  17.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  20.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  26.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  34.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  38.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  47.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  16.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   5.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   8.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.0min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   9.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  12.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=   6.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  10.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.1min
# ...
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.7min
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  24.0s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.3min
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  20.1s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=   8.4s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  24.2s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  17.6s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.5min
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  16.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  15.3s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  42.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  28.6s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  26.4s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  22.0s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.8min
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  21.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  32.6s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  28.9s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  35.9s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  40.3s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  25.5s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=   8.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  36.7s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  17.3s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  17.0s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  31.4s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  29.9s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  14.0s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  18.6s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  26.9s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  52.6s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  24.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  20.1s
# [CV] END mlp__activation=logistic, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  56.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  27.1s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  40.2s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  37.1s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  22.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.5s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  24.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  22.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  32.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  26.5s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  23.9s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  23.5s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  25.6s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  26.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  26.4s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  57.6s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  12.9s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  25.9s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  24.7s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  24.9s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  15.2s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  15.2s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  25.0s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0005; total time=  16.4s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.001; total time=  24.2s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  11.3s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  12.6s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  17.2s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  10.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  12.0s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64), mlp__learning_rate_init=0.0001; total time=  31.2s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  23.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  19.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  16.1s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  25.7s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  13.3s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  14.5s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  23.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  13.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  14.6s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  12.8s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  31.2s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  10.3s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=   9.3s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=   9.0s
# [CV] END mlp__activation=logistic, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  12.9s
#
# Best Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.01, 'mlp__batch_size': 32, 'mlp__hidden_layer_sizes': (256, 128, 64, 32), 'mlp__learning_rate_init': 0.001}
#
# Top 5 configurations:
#    param_mlp__activation  param_mlp__alpha  param_mlp__batch_size  \
# 42                  relu            0.0100                     32
# 24                  relu            0.0010                     32
# 33                  relu            0.0010                     64
# 43                  relu            0.0100                     32
# 15                  relu            0.0001                     64
#
#    param_mlp__hidden_layer_sizes  param_mlp__learning_rate_init  \
# 42            (256, 128, 64, 32)                         0.0010
# 24            (256, 128, 64, 32)                         0.0010
# 33            (256, 128, 64, 32)                         0.0010
# 43            (256, 128, 64, 32)                         0.0005
# 15            (256, 128, 64, 32)                         0.0010
#
#     mean_test_score  std_test_score
# 42           0.3061          0.0063
# 24           0.3054          0.0020
# 33           0.3042          0.0058
# 43           0.3026          0.0032
# 15           0.3017          0.0022
#
# Evaluating MLP on training set...
#
# ===== MLP: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.75      0.90      0.82      4220
#         20.0       0.78      0.63      0.70      3841
#         30.0       0.76      0.74      0.75      3746
#         40.0       0.81      0.60      0.69      3128
#         50.0       0.74      0.85      0.79      2681
#         60.0       0.82      0.86      0.84      1889
#         70.0       0.76      0.91      0.83      1037
#
#     accuracy                           0.77     20542
#    macro avg       0.77      0.79      0.77     20542
# weighted avg       0.77      0.77      0.76     20542
#
#
# Evaluating MLP on validation set...
#
# ===== MLP: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.42      0.55      0.48      1055
#         20.0       0.30      0.23      0.26       961
#         30.0       0.30      0.28      0.29       937
#         40.0       0.27      0.20      0.23       782
#         50.0       0.31      0.36      0.33       670
#         60.0       0.37      0.37      0.37       472
#         70.0       0.36      0.47      0.41       260
#
#     accuracy                           0.34      5137
#    macro avg       0.33      0.35      0.34      5137
# weighted avg       0.33      0.34      0.33      5137
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 best_male_model, train_eval_male, val_eval_male = optimize_mlp_for_gender(
#       2     X_train_male, y_train_male, X_val_male, y_val_male, preprocessing=preprocessing
#       3 )
#
# ValueError: too many values to unpack (expected 3)

# %%
best_female_model, train_eval_female, val_eval_female, results_female = optimize_mlp_for_gender(
    X_train_female, y_train_female, X_val_female, y_val_female, preprocessing=preprocessing
)
# Out:
# Starting grid search for MLP...
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  14.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  19.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  19.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  21.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  22.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  30.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  35.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  48.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  45.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  42.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  39.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  55.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  59.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.0min
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  13.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  18.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  10.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  22.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  14.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  17.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  22.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.2min
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  20.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  26.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  23.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  38.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  38.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  36.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  26.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  43.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  16.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.7min
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  45.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  29.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  17.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  18.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 2.0min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  26.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  25.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.1min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  37.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  44.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  39.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  42.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  55.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  17.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.0min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.2min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  11.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  13.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  22.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  19.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.1min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  19.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.1min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.4min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  21.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  20.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  21.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  29.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  39.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  35.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  42.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  44.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 2.0min
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  48.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  14.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  22.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  26.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  19.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  18.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  30.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.2min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  21.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  42.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.1min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  41.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  39.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  44.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  53.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  22.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.2min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.0min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  14.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  54.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  18.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  23.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  22.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  20.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  31.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  30.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  29.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  35.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  40.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.8min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.8min
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  39.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  54.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  32.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  39.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 2.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  23.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  54.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  32.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  28.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  13.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  38.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  23.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  44.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.4min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  42.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  44.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  34.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  46.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.1min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  56.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  22.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  57.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  20.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  15.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  23.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  25.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  12.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  14.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  22.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  35.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.8min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  29.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  36.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.9min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  43.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  42.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  42.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  50.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  40.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  34.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  32.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  52.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  33.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  40.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.1min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  24.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  13.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  44.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  39.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  37.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  46.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  57.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  59.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  57.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  23.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.2min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  23.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  15.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.6min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  22.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  13.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  14.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  35.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.4min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  38.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.9min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  42.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  28.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  39.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  34.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  19.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  49.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  30.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  19.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 2.5min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  57.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  58.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  26.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.1min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  33.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  34.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  32.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  14.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  32.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  33.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.0min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time= 1.4min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  15.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  27.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.001; total time=  15.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time= 1.7min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  15.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.7min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  25.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.8min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  12.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  22.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0005; total time=  35.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(128, 64, 32), mlp__learning_rate_init=0.0001; total time=  38.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=32, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time= 1.3min
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  32.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  33.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.001; total time=  31.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  33.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  16.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  29.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0005; total time=  41.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  23.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.01, mlp__batch_size=64, mlp__hidden_layer_sizes=(256, 128, 64, 32), mlp__learning_rate_init=0.0001; total time=  35.9s
#
# Best Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.01, 'mlp__batch_size': 64, 'mlp__hidden_layer_sizes': (256, 128, 64, 32), 'mlp__learning_rate_init': 0.001}
#
# Top 5 configurations:
#    param_mlp__activation  param_mlp__alpha  param_mlp__batch_size  \
# 33                  relu            0.0100                     64
# 9                   relu            0.0001                     64
# 21                  relu            0.0010                     64
# 27                  relu            0.0100                     32
# 15                  relu            0.0010                     32
#
#    param_mlp__hidden_layer_sizes  param_mlp__learning_rate_init  \
# 33            (256, 128, 64, 32)                         0.0010
# 9             (256, 128, 64, 32)                         0.0010
# 21            (256, 128, 64, 32)                         0.0010
# 27            (256, 128, 64, 32)                         0.0010
# 15            (256, 128, 64, 32)                         0.0010
#
#     mean_test_score  std_test_score
# 33           0.4415          0.0065
# 9            0.4381          0.0066
# 21           0.4377          0.0124
# 27           0.4362          0.0032
# 15           0.4355          0.0050
#
# Evaluating MLP on training set...
#
# ===== MLP: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.93      0.93      0.93      3045
#         20.0       0.91      0.91      0.91      3623
#         30.0       0.92      0.91      0.92      3573
#         40.0       0.87      0.94      0.90      3049
#         50.0       0.94      0.89      0.92      2720
#         60.0       0.95      0.92      0.94      1469
#         70.0       0.95      0.94      0.95       408
#
#     accuracy                           0.92     17887
#    macro avg       0.93      0.92      0.92     17887
# weighted avg       0.92      0.92      0.92     17887
#
#
# Evaluating MLP on validation set...
#
# ===== MLP: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.58      0.58      0.58       761
#         20.0       0.44      0.43      0.44       906
#         30.0       0.49      0.47      0.48       893
#         40.0       0.45      0.60      0.52       762
#         50.0       0.52      0.45      0.48       680
#         60.0       0.52      0.42      0.47       367
#         70.0       0.54      0.45      0.49       102
#
#     accuracy                           0.50      4471
#    macro avg       0.51      0.49      0.49      4471
# weighted avg       0.50      0.50      0.49      4471

# %%
# Grid search optimize RF:

# Split by gender
X_train_male = X_train[y_train['gender'] == 'male_masculine']
y_train_male = y_train[y_train['gender'] == 'male_masculine']
X_val_male = X_val[y_val['gender'] == 'male_masculine']
y_val_male = y_val[y_val['gender'] == 'male_masculine']

X_train_female = X_train[y_train['gender'] == 'female_feminine']
y_train_female = y_train[y_train['gender'] == 'female_feminine']
X_val_female = X_val[y_val['gender'] == 'female_feminine']
y_val_female = y_val[y_val['gender'] == 'female_feminine']


def optimize_random_forest_for_gender(
    X_train, y_train, X_val, y_val,
    preprocessing,
    param_grid=None
):
    if param_grid is None:
        param_grid = {
            'rf__n_estimators': [200, 400],
            'rf__max_depth': [None, 20, 40],
            'rf__min_samples_split': [2, 5, 10],
            'rf__min_samples_leaf': [1, 2, 4],
            'rf__max_features': ['sqrt']
        }

    rf = RandomForestClassifier(
        random_state=27,
        n_jobs=-1
    )

    pipeline = Pipeline([
        ('preprocessing', preprocessing),
        ('rf', rf)
    ])

    # Create stratification labels from age and gender
    strat_labels = y_train['age'].astype(str) + "-" + y_train['gender']
    stratified_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=27).split(X_train, strat_labels)

    grid_search = GridSearchCV(
        pipeline,
        param_grid=param_grid,
        cv=stratified_cv,
        scoring='accuracy',
        verbose=2,
        n_jobs=-1
    )

    print("Starting grid search for Random Forest...")
    grid_search.fit(X_train, y_train["age"])

    print(f"\nBest Parameters: {grid_search.best_params_}")
    best_model = grid_search.best_estimator_

    # Detailed results as DataFrame
    results_df = pd.DataFrame(grid_search.cv_results_)
    results_df_sorted = results_df.sort_values(by='mean_test_score', ascending=False)
    print("\nTop 5 configurations:")
    display_cols = [col for col in results_df.columns if col.startswith("param_")]
    display_cols += ['mean_test_score', 'std_test_score']
    print(results_df_sorted[display_cols].head())

    # Predictions
    prd_train = best_model.predict(X_train)
    prd_val = best_model.predict(X_val)

    # Evaluation
    evaluate_train = {'RandomForest': prd_train}
    evaluate_val = {'RandomForest': prd_val}

    print("\nEvaluating Random Forest on training set...")
    evaluate_models(y_train["age"], evaluate_train, (12, 8), False, "Training Set")

    print("\nEvaluating Random Forest on validation set...")
    evaluate_models(y_val["age"], evaluate_val, (12, 8), True, "Validation Set")

    return best_model, evaluate_train, evaluate_val, results_df_sorted

# %%
best_rf_male, eval_train_male, eval_val_male, rf_results_male = optimize_random_forest_for_gender(
    X_train_male, y_train_male,
    X_val_male, y_val_male,
    preprocessing= preprocessing
)
# Out:
# Starting grid search for Random Forest...
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  29.4s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  29.8s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  29.8s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  30.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  30.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  58.7s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  28.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  29.4s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  59.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  59.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  28.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  57.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  28.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  57.8s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  57.8s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  54.4s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  54.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  54.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  27.0s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  27.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  27.4s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.4s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  54.0s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  54.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  53.7s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  53.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  26.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  26.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  53.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  26.9s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  27.0s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  26.9s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  27.1s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  54.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  53.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  55.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  53.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  55.1s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.7s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.8s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  54.7s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  55.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  28.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  29.0s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  29.1s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  21.0s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  21.1s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  54.9s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  54.9s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  55.6s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  25.0s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  25.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  56.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  57.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  57.1s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  47.9s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  23.6s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  49.1s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  24.1s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  50.0s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  21.4s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  21.2s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  20.3s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  43.9s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  44.7s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  44.1s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  22.3s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  22.5s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  41.8s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  41.7s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  22.8s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  42.4s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  21.8s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  21.9s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  22.2s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  44.0s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  43.9s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  43.6s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  21.4s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  21.3s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  43.1s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  21.0s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  43.8s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.5s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  43.2s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.2s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  40.8s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.3s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  40.7s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  39.8s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  18.3s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  18.5s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  18.5s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  35.9s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  36.0s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  36.8s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.1s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.5s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.3s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  36.1s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  36.3s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  36.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  28.2s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  35.2s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  35.4s
# [CV] END rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  35.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  28.6s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  28.6s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  55.2s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  56.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  55.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.4s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  54.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  54.4s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.1s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  55.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  28.1s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  28.7s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  28.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  53.6s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  53.3s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  53.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  54.1s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  26.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  53.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  53.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  26.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  26.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  26.3s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  52.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  53.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  52.6s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  25.6s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  25.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  25.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  51.2s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  51.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  51.7s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  26.3s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  25.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  26.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  50.1s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  50.6s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  50.7s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  25.3s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  25.6s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  25.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  50.1s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  49.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  50.5s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  19.6s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  19.2s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  19.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  49.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  50.5s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  19.4s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  19.3s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  38.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  49.8s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  38.4s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  19.7s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  38.4s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.9s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.8s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.5s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  37.6s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  38.0s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  37.4s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  19.2s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  36.6s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  19.0s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  19.2s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  36.5s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  36.4s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  19.0s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  18.8s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  19.4s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  37.0s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  37.5s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  37.5s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.3s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.4s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  36.7s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.8s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  37.3s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  37.0s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  17.9s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  17.7s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  18.1s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  36.1s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  36.0s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  36.1s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  18.5s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  18.5s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  19.5s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  36.0s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  36.8s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  37.0s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.9s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.4s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  18.7s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  36.9s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  36.9s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  36.7s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  34.6s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  34.7s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  29.0s
# [CV] END rf__max_depth=20, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  34.5s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  28.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  29.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  28.8s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  28.6s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  28.5s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  57.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  57.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  57.4s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.8s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  56.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.8s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  56.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.8s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  56.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  28.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  28.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  27.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  54.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  54.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  53.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  27.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  28.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  55.4s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  28.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  55.6s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  54.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.1s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.4s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  54.6s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  55.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  54.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  26.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  26.4s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  26.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  54.6s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  54.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  54.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  28.5s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  29.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  54.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  29.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  55.4s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  55.1s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.7s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  27.7s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  26.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  56.1s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  54.6s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  53.9s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.3s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.8s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.8s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  52.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  52.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  19.9s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  40.1s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  20.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  51.1s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100; total time=  20.3s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  40.4s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  40.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  19.7s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  19.3s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=100; total time=  19.0s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  39.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  40.0s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  40.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.9s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  21.1s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  39.4s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.8s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  39.7s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  40.3s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  21.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  21.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100; total time=  21.8s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  42.4s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  42.7s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  42.5s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  21.1s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  21.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  42.9s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=100; total time=  21.5s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  43.3s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.4s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  43.6s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.3s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=100; total time=  20.5s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  41.3s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  41.4s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  41.6s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  20.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  19.9s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  39.7s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=100; total time=  20.0s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  39.0s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  39.3s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  19.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  19.2s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=100; total time=  19.7s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  37.8s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  36.6s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  31.1s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  25.5s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  25.9s
# [CV] END rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  14.1s
#
# Best Parameters: {'rf__max_depth': 20, 'rf__max_features': 'sqrt', 'rf__min_samples_leaf': 2, 'rf__min_samples_split': 2, 'rf__n_estimators': 200}
#
# Top 5 configurations:
#    param_rf__max_depth param_rf__max_features  param_rf__min_samples_leaf  \
# 43                  20                   sqrt                           2
# 75                  40                   sqrt                           1
# 1                 None                   sqrt                           1
# 37                  20                   sqrt                           1
# 3                 None                   sqrt                           1
#
#     param_rf__min_samples_split  param_rf__n_estimators  mean_test_score  \
# 43                            2                     200           0.3269
# 75                            5                     200           0.3261
# 1                             2                     200           0.3260
# 37                            2                     200           0.3260
# 3                             5                     200           0.3253
#
#     std_test_score
# 43          0.0020
# 75          0.0054
# 1           0.0006
# 37          0.0012
# 3           0.0046
#
# Evaluating Random Forest on training set...
#
# ===== RandomForest: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       1.00      1.00      1.00      4220
#         20.0       1.00      1.00      1.00      3841
#         30.0       1.00      1.00      1.00      3746
#         40.0       1.00      1.00      1.00      3128
#         50.0       1.00      1.00      1.00      2681
#         60.0       1.00      1.00      1.00      1889
#         70.0       1.00      1.00      1.00      1037
#
#     accuracy                           1.00     20542
#    macro avg       1.00      1.00      1.00     20542
# weighted avg       1.00      1.00      1.00     20542
#
#
# Evaluating Random Forest on validation set...
#
# ===== RandomForest: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.37      0.64      0.47      1055
#         20.0       0.27      0.30      0.29       961
#         30.0       0.29      0.41      0.34       937
#         40.0       0.37      0.24      0.30       782
#         50.0       0.62      0.24      0.35       670
#         60.0       0.94      0.19      0.32       472
#         70.0       1.00      0.26      0.41       260
#
#     accuracy                           0.36      5137
#    macro avg       0.55      0.33      0.35      5137
# weighted avg       0.45      0.36      0.35      5137

# %%
best_rf_female, eval_train_female, eval_val_female, rf_results_female = optimize_random_forest_for_gender(
    X_train_female, y_train_female,
    X_val_female, y_val_female,
    preprocessing= preprocessing
)
# Out:
# Starting grid search for Random Forest...
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  47.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  47.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  47.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  47.7s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  48.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  46.1s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  45.3s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  48.1s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  48.0s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  45.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  45.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  44.2s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  44.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  44.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  44.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  43.4s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  43.8s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  42.8s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  43.8s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  43.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  43.4s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  41.7s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  42.0s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  41.6s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  43.0s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  43.5s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  43.4s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  46.7s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  47.7s
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  45.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  45.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  44.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  44.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  43.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  44.3s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  42.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  44.3s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  44.7s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  44.3s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  50.4s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  51.3s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  50.7s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.7min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  51.2s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  51.2s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  51.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.7min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.7min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.7min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  46.9s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  47.1s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  46.1s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  43.8s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  43.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  43.2s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  41.4s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  40.6s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  41.0s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  48.7s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  48.5s
# [CV] END rf__max_depth=20, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=  48.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  48.7s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  48.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=  48.4s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.7min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  49.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  49.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=  47.1s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.7min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  45.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.6min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  44.6s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=  45.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  44.4s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  44.1s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=  45.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  42.4s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  42.8s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=  43.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  41.6s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  41.4s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.5min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=  41.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  42.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  42.1s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=  42.8s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  43.0s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  41.7s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=  41.2s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=400; total time= 1.4min
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=400; total time=  58.3s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=400; total time=  57.9s
# [CV] END rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=400; total time=  47.5s
#
# Best Parameters: {'rf__max_depth': 40, 'rf__max_features': 'sqrt', 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 5, 'rf__n_estimators': 400}
#
# Top 5 configurations:
#    param_rf__max_depth param_rf__max_features  param_rf__min_samples_leaf  \
# 39                  40                   sqrt                           1
# 1                 None                   sqrt                           1
# 3                 None                   sqrt                           1
# 37                  40                   sqrt                           1
# 19                  20                   sqrt                           1
#
#     param_rf__min_samples_split  param_rf__n_estimators  mean_test_score  \
# 39                            5                     400           0.4682
# 1                             2                     400           0.4681
# 3                             5                     400           0.4680
# 37                            2                     400           0.4675
# 19                            2                     400           0.4672
#
#     std_test_score
# 39          0.0060
# 1           0.0047
# 3           0.0057
# 37          0.0038
# 19          0.0053
#
# Evaluating Random Forest on training set...
#
# ===== RandomForest: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       1.00      1.00      1.00      3045
#         20.0       1.00      1.00      1.00      3623
#         30.0       1.00      1.00      1.00      3573
#         40.0       1.00      1.00      1.00      3049
#         50.0       1.00      1.00      1.00      2720
#         60.0       1.00      1.00      1.00      1469
#         70.0       1.00      1.00      1.00       408
#
#     accuracy                           1.00     17887
#    macro avg       1.00      1.00      1.00     17887
# weighted avg       1.00      1.00      1.00     17887
#
#
# Evaluating Random Forest on validation set...
#
# ===== RandomForest: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.64      0.62      0.63       761
#         20.0       0.43      0.53      0.47       906
#         30.0       0.45      0.64      0.53       893
#         40.0       0.62      0.56      0.59       762
#         50.0       0.66      0.50      0.57       680
#         60.0       0.96      0.33      0.49       367
#         70.0       1.00      0.27      0.43       102
#
#     accuracy                           0.54      4471
#    macro avg       0.68      0.49      0.53      4471
# weighted avg       0.59      0.54      0.54      4471

# %%
# optimiser for gradient boosting

# Split by gender
X_train_male = X_train[y_train['gender'] == 'male_masculine']
y_train_male = y_train[y_train['gender'] == 'male_masculine']
X_val_male = X_val[y_val['gender'] == 'male_masculine']
y_val_male = y_val[y_val['gender'] == 'male_masculine']

X_train_female = X_train[y_train['gender'] == 'female_feminine']
y_train_female = y_train[y_train['gender'] == 'female_feminine']
X_val_female = X_val[y_val['gender'] == 'female_feminine']
y_val_female = y_val[y_val['gender'] == 'female_feminine']


def optimize_gradient_boosting_for_gender(
    X_train, y_train, X_val, y_val,
    preprocessing,
    param_grid=None
):
    if param_grid is None:
        param_grid = {
            'gb__learning_rate': [0.1, 0.05],
            'gb__max_iter': [100, 200],
            'gb__max_leaf_nodes': [31, 63],
            'gb__min_samples_leaf': [20, 50],
            'gb__max_bins': [255],
            'gb__l2_regularization': [0.0, 1.0],
            'gb__max_depth': [None, 10],
        }

    gb = HistGradientBoostingClassifier(
        random_state=27
    )

    pipeline = Pipeline([
        ('preprocessing', preprocessing),
        ('gb', gb)
    ])

    # Create stratification labels from age and gender
    strat_labels = y_train['age'].astype(str) + "-" + y_train['gender']
    stratified_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=27).split(X_train, strat_labels)

    grid_search = GridSearchCV(
        pipeline,
        param_grid=param_grid,
        cv=stratified_cv,
        scoring=qwk_scorer,  # Make sure this is defined earlier in your code
        verbose=2,
        n_jobs=-1
    )

    print("Starting grid search for Gradient Boosting...")
    grid_search.fit(X_train, y_train["age"])

    print(f"\nBest Parameters: {grid_search.best_params_}")
    best_model = grid_search.best_estimator_

    # Detailed results as DataFrame
    results_df = pd.DataFrame(grid_search.cv_results_)
    results_df_sorted = results_df.sort_values(by='mean_test_score', ascending=False)
    print("\nTop 5 configurations:")
    display_cols = [col for col in results_df.columns if col.startswith("param_")]
    display_cols += ['mean_test_score', 'std_test_score']
    print(results_df_sorted[display_cols].head())

    # Predictions
    prd_train = best_model.predict(X_train)
    prd_val = best_model.predict(X_val)

    # Evaluation
    evaluate_train = {'GradientBoosting': prd_train}
    evaluate_val = {'GradientBoosting': prd_val}

    print("\nEvaluating Gradient Boosting on training set...")
    evaluate_models(y_train["age"], evaluate_train, (12, 8), False, "Training Set")

    print("\nEvaluating Gradient Boosting on validation set...")
    evaluate_models(y_val["age"], evaluate_val, (12, 8), True, "Validation Set")

    return best_model, evaluate_train, evaluate_val, results_df_sorted

# %%
best_gb_male, eval_train_gb_male, eval_val_gb_male, gb_results_male = optimize_gradient_boosting_for_gender(
    X_train_male, y_train_male,
    X_val_male, y_val_male,
    preprocessing= preprocessing
)
# Out:
# Starting grid search for Gradient Boosting...
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  19.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  22.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  23.6s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  25.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  25.4s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  26.7s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  30.5s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  33.2s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  26.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  22.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  18.4s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  25.3s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  26.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  29.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  20.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  31.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  26.2s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  28.5s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  24.5s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  28.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  24.6s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  33.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  31.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  32.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  20.6s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  21.4s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  20.5s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  27.4s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  25.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  23.5s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  26.5s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  23.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  25.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  17.5s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  23.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  21.7s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  26.6s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  18.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  25.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  23.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  17.5s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  24.2s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  23.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  25.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  25.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  23.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  27.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  21.4s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  24.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  24.6s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  25.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  23.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  24.5s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  24.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  44.7s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  45.2s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  43.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  41.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  41.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  40.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  39.2s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  45.7s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  36.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  45.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  40.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  42.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  42.3s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  48.2s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  51.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  50.3s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  24.2s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  39.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  23.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  23.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  23.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  22.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  22.7s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  46.8s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  38.4s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  39.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  34.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  38.6s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  32.7s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  34.0s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  33.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  39.2s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  38.9s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  37.3s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  43.3s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  42.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  40.7s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  48.1s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  57.6s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  46.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  25.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  21.8s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  24.6s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  42.8s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  21.6s
# [CV] END gb__l2_regularization=0.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  44.6s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  23.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  23.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  22.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  32.7s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  25.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  34.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  22.7s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  29.1s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  22.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  31.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  34.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  21.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  27.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  30.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  22.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  34.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  24.5s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  22.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  31.5s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  26.1s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  21.6s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  19.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  18.7s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  19.8s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  19.7s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  20.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  19.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  22.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  19.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  25.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  19.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  34.7s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  19.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  18.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  18.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  19.8s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  20.7s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  22.7s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  19.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  22.7s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  26.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  20.1s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  36.6s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.1, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  19.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  22.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  22.5s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  22.5s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  21.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  21.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  21.1s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  40.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  40.5s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  36.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  36.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  40.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  31.7s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  35.6s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  43.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  38.8s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  41.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  44.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  42.5s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  49.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  22.8s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  22.8s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  50.5s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time= 1.1min
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  21.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time= 1.3min
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  20.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  20.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  20.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  49.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=None, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  51.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  39.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  39.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  34.8s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  40.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  35.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=100, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  35.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  37.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  46.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  33.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=20; total time=  45.6s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  39.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=31, gb__min_samples_leaf=50; total time=  39.2s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  45.4s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  45.9s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  26.0s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=20; total time=  44.1s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  36.3s
# [CV] END gb__l2_regularization=1.0, gb__learning_rate=0.05, gb__max_bins=255, gb__max_depth=10, gb__max_iter=200, gb__max_leaf_nodes=63, gb__min_samples_leaf=50; total time=  22.6s
#
# Best Parameters: {'gb__l2_regularization': 1.0, 'gb__learning_rate': 0.05, 'gb__max_bins': 255, 'gb__max_depth': None, 'gb__max_iter': 200, 'gb__max_leaf_nodes': 31, 'gb__min_samples_leaf': 50}
#
# Top 5 configurations:
#     param_gb__l2_regularization  param_gb__learning_rate  param_gb__max_bins  \
# 53                       1.0000                   0.0500                 255
# 61                       1.0000                   0.0500                 255
# 29                       0.0000                   0.0500                 255
# 31                       0.0000                   0.0500                 255
# 60                       1.0000                   0.0500                 255
#
#    param_gb__max_depth  param_gb__max_iter  param_gb__max_leaf_nodes  \
# 53                None                 200                        31
# 61                  10                 200                        31
# 29                  10                 200                        31
# 31                  10                 200                        63
# 60                  10                 200                        31
#
#     param_gb__min_samples_leaf  mean_test_score  std_test_score
# 53                          50           0.3366          0.0024
# 61                          50           0.3364          0.0044
# 29                          50           0.3353          0.0062
# 31                          50           0.3351          0.0032
# 60                          20           0.3346          0.0014
#
# Evaluating Gradient Boosting on training set...
#
# ===== GradientBoosting: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.83      0.92      0.87      4220
#         20.0       0.88      0.88      0.88      3841
#         30.0       0.85      0.88      0.86      3746
#         40.0       0.90      0.84      0.87      3128
#         50.0       0.92      0.86      0.89      2681
#         60.0       0.96      0.87      0.91      1889
#         70.0       0.98      0.92      0.95      1037
#
#     accuracy                           0.88     20542
#    macro avg       0.90      0.88      0.89     20542
# weighted avg       0.88      0.88      0.88     20542
#
#
# Evaluating Gradient Boosting on validation set...
#
# ===== GradientBoosting: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.41      0.56      0.47      1055
#         20.0       0.29      0.31      0.30       961
#         30.0       0.29      0.36      0.33       937
#         40.0       0.28      0.24      0.26       782
#         50.0       0.36      0.26      0.30       670
#         60.0       0.51      0.25      0.33       472
#         70.0       0.74      0.28      0.41       260
#
#     accuracy                           0.35      5137
#    macro avg       0.41      0.32      0.34      5137
# weighted avg       0.37      0.35      0.34      5137

# %%
best_gb_female, eval_train_gb_female, eval_val_gb_female, gb_results_female = optimize_gradient_boosting_for_gender(
    X_train_female, y_train_female,
    X_val_female, y_val_female,
    preprocessing= preprocessing
)

# %%
y_train_multi = np.column_stack((y_train["age"], y_train["age_young_old_encoded"]))
y_val_multi = np.column_stack((y_val["age"], y_val["age_young_old_encoded"]))

# Base model (intentionally large)
base_clf = RandomForestClassifier(
    n_estimators=500,          # Big forest
    max_depth=20,            
    min_samples_split=2,       # Allow aggressive splitting
    min_samples_leaf=1,        # Smallest possible leaves
    max_features='sqrt',       # Good default for classification
    bootstrap=False,            # Enable bagging
    class_weight=None,         # Let it learn naturally, change to 'balanced' if needed
    oob_score=False,           # Could enable if bootstrap is True
    n_jobs=-1,                 # Use all CPUs
    random_state=42,           # For reproducibility
    verbose=0
)

# Wrap as multi-output
multi_clf = MultiOutputClassifier(base_clf)

fit_predict_gender_age_pipeline_with_joint_comparison(
    MLPClassifier(hidden_layer_sizes=(128, 64, 32),
                batch_size=64,
                learning_rate_init=0.001,
                max_iter=1000,
              activation="relu",
              random_state=27,
              learning_rate='adaptive',
              alpha=0.0001),
        multi_clf, multi_clf,
     "MLPClassifier for Gender",
    "Multi-Class for Age", 
    X_train=X_train, y_train_age=y_train_multi, y_train_gender=y_train["gender"], X_val=X_val, y_val_age=y_val_multi, y_val_gender=y_val["gender"],
    numerical=False, binning=identity, multiclass=True)
# Out:
# Fitting MLPClassifier for Gender on training set
#
# Predicting MLPClassifier for Gender on training set
#
# Predicting MLPClassifier for Gender on validation set
#
# MLPClassifier for Gender Gender Model - Training Set:
#                  precision    recall  f1-score   support
#
# female_feminine       1.00      1.00      1.00     17915
#  male_masculine       1.00      1.00      1.00     22885
#
#        accuracy                           1.00     40800
#       macro avg       1.00      1.00      1.00     40800
#    weighted avg       1.00      1.00      1.00     40800
#
#
# MLPClassifier for Gender Gender Model - Validation Set:
#                  precision    recall  f1-score   support
#
# female_feminine       0.91      0.92      0.92      4478
#  male_masculine       0.94      0.93      0.93      5722
#
#        accuracy                           0.93     10200
#       macro avg       0.92      0.93      0.92     10200
#    weighted avg       0.93      0.93      0.93     10200
# Fitting Multi-Class for Age on Gender Female
#
# Fitting Multi-Class for Age on Gender Male
# Predicting Multi-Class for Age on validation set: 100%|██████████| 10200/10200 [48:55<00:00,  3.47it/s]
# Multi-Class for Age - Prediction Report on Gender female_feminine: Routed by True Gender
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.67      0.74      1928
#          1.0       0.78      0.88      0.83      2550
#
#     accuracy                           0.79      4478
#    macro avg       0.80      0.78      0.78      4478
# weighted avg       0.79      0.79      0.79      4478
# Multi-Class for Age - Prediction Report on Gender male_masculine: Routed by True Gender
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.83      0.75      3172
#          1.0       0.70      0.51      0.59      2550
#
#     accuracy                           0.69      5722
#    macro avg       0.69      0.67      0.67      5722
# weighted avg       0.69      0.69      0.68      5722
# Multi-Class for Age - Prediction Report on Gender total: Routed by True Gender
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.77      0.74      5100
#          1.0       0.75      0.70      0.72      5100
#
#     accuracy                           0.73     10200
#    macro avg       0.73      0.73      0.73     10200
# weighted avg       0.73      0.73      0.73     10200
# Multi-Class for Age - Prediction Report on Gender female_feminine: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.66      0.72      1928
#          1.0       0.77      0.87      0.82      2550
#
#     accuracy                           0.78      4478
#    macro avg       0.78      0.76      0.77      4478
# weighted avg       0.78      0.78      0.77      4478
# Multi-Class for Age - Prediction Report on Gender male_masculine: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.81      0.74      3172
#          1.0       0.69      0.52      0.59      2550
#
#     accuracy                           0.68      5722
#    macro avg       0.68      0.66      0.66      5722
# weighted avg       0.68      0.68      0.67      5722
# Multi-Class for Age - Prediction Report on Gender total: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.75      0.73      5100
#          1.0       0.74      0.69      0.71      5100
#
#     accuracy                           0.72     10200
#    macro avg       0.72      0.72      0.72     10200
# weighted avg       0.72      0.72      0.72     10200
#  Routing Error Cost (Accuracy Loss from using predicted gender): 0.0101
# {'acc_true_gender': 0.7333333333333333,
#  'acc_pred_gender': 0.7232352941176471,
#  'routing_error_cost': 0.010098039215686194}

# %%
#Postbinned Classifier
fit_predict_gender_age_pipeline_with_joint_comparison(
    MLPClassifier(hidden_layer_sizes=(128, 64, 32),
                batch_size=64,
                learning_rate_init=0.001,
                max_iter=1000,
              activation="relu",
              random_state=27,
              learning_rate='adaptive',
              alpha=0.0001),

    RandomForestClassifier(max_depth=20, max_features='sqrt', min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=27),
    RandomForestClassifier(max_depth=40, max_features='sqrt', min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=27),
    "MLPClassifier for Gender",
    "Post-Binned Random Forest for Age", 
    X_train=X_train, y_train_age=y_train["age"], y_train_gender=y_train["gender"], X_val=X_val, y_val_age=y_val["age"], y_val_gender=y_val["gender"],
    numerical=False, binning=bin_age_young_old)
# Out:
# Fitting MLPClassifier for Gender on training set
#
# Predicting MLPClassifier for Gender on training set
#
# Predicting MLPClassifier for Gender on validation set
#
# MLPClassifier for Gender Gender Model - Training Set:
#                  precision    recall  f1-score   support
#
# female_feminine       1.00      1.00      1.00     17915
#  male_masculine       1.00      1.00      1.00     22885
#
#        accuracy                           1.00     40800
#       macro avg       1.00      1.00      1.00     40800
#    weighted avg       1.00      1.00      1.00     40800
#
#
# MLPClassifier for Gender Gender Model - Validation Set:
#                  precision    recall  f1-score   support
#
# female_feminine       0.91      0.92      0.92      4478
#  male_masculine       0.94      0.93      0.93      5722
#
#        accuracy                           0.93     10200
#       macro avg       0.92      0.93      0.92     10200
#    weighted avg       0.93      0.93      0.93     10200
# Fitting Post-Binned Random Forest for Age on Gender Female
#
# Fitting Post-Binned Random Forest for Age on Gender Male
# Predicting Post-Binned Random Forest for Age on validation set: 100%|██████████| 10200/10200 [06:53<00:00, 24.70it/s]
# Post-Binned Random Forest for Age - Prediction Report on Gender female_feminine: Routed by True Gender
#               precision    recall  f1-score   support
#
#          old       0.88      0.55      0.68      1928
#        young       0.74      0.94      0.83      2550
#
#     accuracy                           0.77      4478
#    macro avg       0.81      0.75      0.75      4478
# weighted avg       0.80      0.77      0.76      4478
# Post-Binned Random Forest for Age - Prediction Report on Gender male_masculine: Routed by True Gender
#               precision    recall  f1-score   support
#
#          old       0.71      0.62      0.66      3172
#        young       0.59      0.69      0.64      2550
#
#     accuracy                           0.65      5722
#    macro avg       0.65      0.66      0.65      5722
# weighted avg       0.66      0.65      0.65      5722
# Post-Binned Random Forest for Age - Prediction Report on Gender total: Routed by True Gender
#               precision    recall  f1-score   support
#
#          old       0.76      0.59      0.67      5100
#        young       0.67      0.82      0.74      5100
#
#     accuracy                           0.71     10200
#    macro avg       0.72      0.71      0.70     10200
# weighted avg       0.72      0.71      0.70     10200
# Post-Binned Random Forest for Age - Prediction Report on Gender female_feminine: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#          old       0.86      0.53      0.66      1928
#        young       0.73      0.93      0.82      2550
#
#     accuracy                           0.76      4478
#    macro avg       0.79      0.73      0.74      4478
# weighted avg       0.78      0.76      0.75      4478
# Post-Binned Random Forest for Age - Prediction Report on Gender male_masculine: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#          old       0.71      0.61      0.66      3172
#        young       0.59      0.69      0.63      2550
#
#     accuracy                           0.65      5722
#    macro avg       0.65      0.65      0.65      5722
# weighted avg       0.65      0.65      0.65      5722
# Post-Binned Random Forest for Age - Prediction Report on Gender total: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#          old       0.75      0.58      0.66      5100
#        young       0.66      0.81      0.73      5100
#
#     accuracy                           0.70     10200
#    macro avg       0.71      0.70      0.69     10200
# weighted avg       0.71      0.70      0.69     10200
#  Routing Error Cost (Accuracy Loss from using predicted gender): 0.0094
# {'acc_true_gender': 0.7054901960784313,
#  'acc_pred_gender': 0.696078431372549,
#  'routing_error_cost': 0.009411764705882342}

# %%
#Prebinned Classifier
fit_predict_gender_age_pipeline_with_joint_comparison(
    MLPClassifier(hidden_layer_sizes=(128, 64, 32),
                batch_size=64,
                learning_rate_init=0.001,
                max_iter=1000,
              activation="relu",
              random_state=27,
              learning_rate='adaptive',
              alpha=0.0001),

    RandomForestClassifier(max_depth=20, max_features='sqrt', min_samples_leaf=2, min_samples_split=2, n_estimators=300, random_state=27),
    RandomForestClassifier(max_depth=40, max_features='sqrt', min_samples_leaf=1, min_samples_split=5, n_estimators=300, random_state=27),
    "MLPClassifier for Gender",
    "Pre-Binned Random Forest for Age", 
    X_train=X_train, y_train_age=y_train["age_young_old"], y_train_gender=y_train["gender"], X_val=X_val, y_val_age=y_val["age_young_old"], y_val_gender=y_val["gender"],
    numerical=False, binning=identity)
# Out:
# Fitting MLPClassifier for Gender on training set
#
# Predicting MLPClassifier for Gender on training set
#
# Predicting MLPClassifier for Gender on validation set
#
# MLPClassifier for Gender Gender Model - Training Set:
#                  precision    recall  f1-score   support
#
# female_feminine       1.00      1.00      1.00     17915
#  male_masculine       1.00      1.00      1.00     22885
#
#        accuracy                           1.00     40800
#       macro avg       1.00      1.00      1.00     40800
#    weighted avg       1.00      1.00      1.00     40800
#
#
# MLPClassifier for Gender Gender Model - Validation Set:
#                  precision    recall  f1-score   support
#
# female_feminine       0.91      0.92      0.92      4478
#  male_masculine       0.94      0.93      0.93      5722
#
#        accuracy                           0.93     10200
#       macro avg       0.92      0.93      0.92     10200
#    weighted avg       0.93      0.93      0.93     10200
# Fitting Pre-Binned Random Forest for Age on Gender Female
#
# Fitting Pre-Binned Random Forest for Age on Gender Male
# Predicting Pre-Binned Random Forest for Age on validation set: 100%|██████████| 10200/10200 [06:43<00:00, 25.30it/s]
# Pre-Binned Random Forest for Age - Prediction Report on Gender female_feminine: Routed by True Gender
#               precision    recall  f1-score   support
#
#            0       0.80      0.65      0.71      1928
#            1       0.77      0.88      0.82      2550
#
#     accuracy                           0.78      4478
#    macro avg       0.78      0.76      0.77      4478
# weighted avg       0.78      0.78      0.77      4478
# Pre-Binned Random Forest for Age - Prediction Report on Gender male_masculine: Routed by True Gender
#               precision    recall  f1-score   support
#
#            0       0.66      0.86      0.75      3172
#            1       0.72      0.46      0.56      2550
#
#     accuracy                           0.68      5722
#    macro avg       0.69      0.66      0.65      5722
# weighted avg       0.69      0.68      0.66      5722
# Pre-Binned Random Forest for Age - Prediction Report on Gender total: Routed by True Gender
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74      5100
#            1       0.75      0.67      0.71      5100
#
#     accuracy                           0.72     10200
#    macro avg       0.72      0.72      0.72     10200
# weighted avg       0.72      0.72      0.72     10200
# Pre-Binned Random Forest for Age - Prediction Report on Gender female_feminine: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#            0       0.77      0.64      0.70      1928
#            1       0.76      0.86      0.81      2550
#
#     accuracy                           0.76      4478
#    macro avg       0.77      0.75      0.75      4478
# weighted avg       0.76      0.76      0.76      4478
# Pre-Binned Random Forest for Age - Prediction Report on Gender male_masculine: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#            0       0.66      0.84      0.74      3172
#            1       0.70      0.47      0.56      2550
#
#     accuracy                           0.67      5722
#    macro avg       0.68      0.65      0.65      5722
# weighted avg       0.68      0.67      0.66      5722
# Pre-Binned Random Forest for Age - Prediction Report on Gender total: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73      5100
#            1       0.74      0.66      0.70      5100
#
#     accuracy                           0.71     10200
#    macro avg       0.72      0.71      0.71     10200
# weighted avg       0.72      0.71      0.71     10200
#  Routing Error Cost (Accuracy Loss from using predicted gender): 0.0080
# {'acc_true_gender': 0.721764705882353,
#  'acc_pred_gender': 0.7137254901960784,
#  'routing_error_cost': 0.008039215686274526}

# %%
#Prebinned Classifier Double MLP
fit_predict_gender_age_pipeline_with_joint_comparison(
    MLPClassifier(hidden_layer_sizes=(512, 256),
                batch_size=64,
                learning_rate_init=0.001,
                max_iter=1000,
              activation="relu",
              random_state=27,
              learning_rate='adaptive',
              alpha=0.0001),

    
    MLPClassifier(hidden_layer_sizes=(512, 256),
                batch_size=64,
                learning_rate_init=0.001,
                max_iter=1000,
              activation="relu",
              random_state=27,
              learning_rate='adaptive',
              alpha=0.001, solver='adam'),
    MLPClassifier(hidden_layer_sizes=(512, 256),
                batch_size=64,
                learning_rate_init=0.001,
                max_iter=1000,
              activation="relu",
              random_state=27,
              learning_rate='adaptive',
              alpha=0.001, solver='adam'),
    "MLPClassifier for Gender",
    "Pre-Binned Wide MLP for Age", 
    X_train=X_train, y_train_age=y_train["age_young_old"], y_train_gender=y_train["gender"], X_val=X_val, y_val_age=y_val["age_young_old"], y_val_gender=y_val["gender"],
    numerical=False, binning=identity)
# Out:
# Fitting MLPClassifier for Gender on training set
#
# Predicting MLPClassifier for Gender on training set
#
# Predicting MLPClassifier for Gender on validation set
#
# MLPClassifier for Gender Gender Model - Training Set:
#                  precision    recall  f1-score   support
#
# female_feminine       1.00      1.00      1.00     17915
#  male_masculine       1.00      1.00      1.00     22885
#
#        accuracy                           1.00     40800
#       macro avg       1.00      1.00      1.00     40800
#    weighted avg       1.00      1.00      1.00     40800
#
#
# MLPClassifier for Gender Gender Model - Validation Set:
#                  precision    recall  f1-score   support
#
# female_feminine       0.91      0.92      0.92      4478
#  male_masculine       0.94      0.93      0.93      5722
#
#        accuracy                           0.93     10200
#       macro avg       0.92      0.93      0.93     10200
#    weighted avg       0.93      0.93      0.93     10200
# Fitting Pre-Binned Wide MLP for Age on Gender Female
#
# Fitting Pre-Binned Wide MLP for Age on Gender Male
# Predicting Pre-Binned Wide MLP for Age on validation set: 100%|██████████| 10200/10200 [01:13<00:00, 138.29it/s]
# Pre-Binned Wide MLP for Age - Prediction Report on Gender female_feminine: Routed by True Gender
#               precision    recall  f1-score   support
#
#          old       0.78      0.81      0.79      1928
#        young       0.85      0.83      0.84      2550
#
#     accuracy                           0.82      4478
#    macro avg       0.81      0.82      0.81      4478
# weighted avg       0.82      0.82      0.82      4478
# Pre-Binned Wide MLP for Age - Prediction Report on Gender male_masculine: Routed by True Gender
#               precision    recall  f1-score   support
#
#          old       0.72      0.74      0.73      3172
#        young       0.67      0.64      0.65      2550
#
#     accuracy                           0.70      5722
#    macro avg       0.69      0.69      0.69      5722
# weighted avg       0.69      0.70      0.69      5722
# Pre-Binned Wide MLP for Age - Prediction Report on Gender total: Routed by True Gender
#               precision    recall  f1-score   support
#
#          old       0.74      0.77      0.75      5100
#        young       0.76      0.73      0.74      5100
#
#     accuracy                           0.75     10200
#    macro avg       0.75      0.75      0.75     10200
# weighted avg       0.75      0.75      0.75     10200
# Pre-Binned Wide MLP for Age - Prediction Report on Gender female_feminine: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#          old       0.77      0.78      0.77      1928
#        young       0.83      0.82      0.83      2550
#
#     accuracy                           0.80      4478
#    macro avg       0.80      0.80      0.80      4478
# weighted avg       0.80      0.80      0.80      4478
# Pre-Binned Wide MLP for Age - Prediction Report on Gender male_masculine: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#          old       0.71      0.74      0.72      3172
#        young       0.66      0.62      0.64      2550
#
#     accuracy                           0.69      5722
#    macro avg       0.68      0.68      0.68      5722
# weighted avg       0.69      0.69      0.69      5722
# Pre-Binned Wide MLP for Age - Prediction Report on Gender total: Routed by Predicted Gender
#               precision    recall  f1-score   support
#
#          old       0.73      0.76      0.74      5100
#        young       0.75      0.72      0.73      5100
#
#     accuracy                           0.74     10200
#    macro avg       0.74      0.74      0.74     10200
# weighted avg       0.74      0.74      0.74     10200
#  Routing Error Cost (Accuracy Loss from using predicted gender): 0.0109
# {'acc_true_gender': 0.7492156862745099,
#  'acc_pred_gender': 0.7383333333333333,
#  'routing_error_cost': 0.010882352941176565}

# %% [markdown]
# ## Soft Age Prediction

# %%
def fit_predict_gender_age_pipeline_with_soft_feature(
    gender_model_class,
    age_model_class,
    gender_model_name="GenderModel",
    age_model_name="AgeModel",
    X_train=X_train, y_train_gender=y_train['gender'],y_train_age=y_train['gender'], X_val=X_val,
    y_val_gender=y_val['gender'],y_val_age=y_val['age'],
    binning=identity, numerical=True, multiclass=False):
    
    
    # ====== Fit gender model ======
    pipe_gender = make_pipeline(clone(preprocessing), clone(gender_model_class))
    print(f"\nFitting {gender_model_name} on training set")
    pipe_gender.fit(X_train, y_train_gender)

    # Predict gender probability (for 'male_masculine')
    print(f"\nPredict probability of {gender_model_name} on training set")
    prob_gender_train = pipe_gender.predict_proba(X_train)[:, 1]
    print(f"\nPredict probability of {gender_model_name} on validation set")
    prob_gender_val = pipe_gender.predict_proba(X_val)[:, 1]
    true_gender_binary_val = (y_val['gender'] == 'male_masculine').astype(int)

    # ====== Evaluate gender model ======
    predicted_gender_val = pipe_gender.predict(X_val)
    print(f"\n{gender_model_name} Gender Model - Validation Set Classification Report:")
    print(classification_report(y_val_gender, predicted_gender_val))

    auc_score = roc_auc_score(true_gender_binary_val, prob_gender_val)
    logloss = log_loss(true_gender_binary_val, prob_gender_val)
    print(f"AUC-ROC for Gender Probabilities: {auc_score:.4f}")
    print(f"Log Loss for Gender Probabilities: {logloss:.4f}")

    RocCurveDisplay.from_predictions(true_gender_binary_val, prob_gender_val)
    plt.title("ROC Curve - Gender Probabilities")
    plt.show()

    prob_true, prob_pred = calibration_curve(true_gender_binary_val, prob_gender_val, n_bins=10)
    plt.plot(prob_pred, prob_true, marker='o')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel("Mean Predicted Probability")
    plt.ylabel("Fraction of Positives")
    plt.title("Calibration Curve - Gender Probabilities")
    plt.show()

    # ====== Append gender prob to features ======
    X_train_aug = X_train.copy()
    X_val_aug = X_val.copy()
    X_train_aug['prob_gender_male'] = prob_gender_train
    X_val_aug['prob_gender_male'] = prob_gender_val

    # ====== Fit age model ======
    age_model = make_pipeline(clone(preprocessing), clone(age_model_class))
    print(f"\nFitting {age_model_name} with gender probability feature")
    age_model.fit(X_train_aug, y_train_age)
    print(f"\nPredicting {age_model_name} on training set")
    pred_train=age_model.predict(X_train_aug)
    print(f"\nPredicting {age_model_name} on validation set")
    pred_val = age_model.predict(X_val_aug)
    
    if multiclass:
        y_train_age = y_train_age[:, 1]
        y_val_age = y_val_age[:, 1]
        pred_train = pred_train[:, 1]
        pred_val = pred_val[:, 1]
        
    
    evaluate_models(y_train_age, {age_model_name : pred_train}, (12, 8), False, "Training Set", numerical=numerical, binning=binning)

    # ====== Predict age ======
    return evaluate_models(y_val_age, {age_model_name : pred_val}, (12, 8), True, "Validation Set", numerical=numerical, binning=binning)

# %%
fit_predict_gender_age_pipeline_with_soft_feature(KNeighborsClassifier(n_neighbors=5), KNeighborsClassifier(n_neighbors=5), "KNN by Gender", "KNN by Age")
# Out:
# KNN by Gender Gender Model - Validation Set Classification Report:
#                  precision    recall  f1-score   support
#
# female_feminine       0.87      0.88      0.87      3946
#  male_masculine       0.89      0.89      0.89      4532
#
#        accuracy                           0.88      8478
#       macro avg       0.88      0.88      0.88      8478
#    weighted avg       0.88      0.88      0.88      8478
#
# AUC-ROC for Gender Probabilities: 0.9431
# Log Loss for Gender Probabilities: 0.7409
# Fitting KNN by Age with gender probability feature
#
# ===== KNN by Age: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.63      0.81      0.71      7479
#         20.0       0.65      0.62      0.64      7684
#         30.0       0.66      0.65      0.66      7534
#         40.0       0.69      0.66      0.67      6359
#         50.0       0.74      0.66      0.70      5559
#         60.0       0.78      0.66      0.71      3457
#         70.0       0.80      0.71      0.75      1488
#
#     accuracy                           0.68     39560
#    macro avg       0.71      0.68      0.69     39560
# weighted avg       0.68      0.68      0.68     39560
#
#
# ===== KNN by Age: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.44      0.59      0.51      1602
#         20.0       0.38      0.35      0.36      1648
#         30.0       0.42      0.43      0.42      1615
#         40.0       0.46      0.45      0.46      1363
#         50.0       0.48      0.40      0.44      1191
#         60.0       0.55      0.44      0.49       740
#         70.0       0.55      0.43      0.49       319
#
#     accuracy                           0.45      8478
#    macro avg       0.47      0.44      0.45      8478
# weighted avg       0.45      0.45      0.44      8478
#         Model  Accuracy  Precision  Recall  F1-score
# 0  KNN by Age    0.4455     0.4485  0.4455    0.4434

# %%
fit_predict_gender_age_pipeline_with_soft_feature(
    RandomForestClassifier(n_estimators=100, random_state=27),
    MLPClassifier(hidden_layer_sizes=(128, 64, 32), max_iter=2000, random_state=27, batch_size=32, learning_rate='adaptive', learning_rate_init=0.0005, alpha=0.001, early_stopping=True, validation_fraction=0.1),
    "Random Forest for Gender", "MLP for Age")
# Out:
# Random Forest for Gender Gender Model - Validation Set Classification Report:
#                  precision    recall  f1-score   support
#
# female_feminine       0.88      0.88      0.88      3946
#  male_masculine       0.89      0.89      0.89      4532
#
#        accuracy                           0.89      8478
#       macro avg       0.89      0.88      0.89      8478
#    weighted avg       0.89      0.89      0.89      8478
#
# AUC-ROC for Gender Probabilities: 0.9522
# Log Loss for Gender Probabilities: 0.3281
# Fitting MLP for Age with gender probability feature
#
# ===== MLP for Age: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.53      0.64      0.58      7479
#         20.0       0.42      0.44      0.43      7684
#         30.0       0.43      0.43      0.43      7534
#         40.0       0.44      0.39      0.41      6359
#         50.0       0.45      0.49      0.47      5559
#         60.0       0.49      0.34      0.40      3457
#         70.0       0.58      0.35      0.44      1488
#
#     accuracy                           0.46     39560
#    macro avg       0.48      0.44      0.45     39560
# weighted avg       0.46      0.46      0.46     39560
#
#
# ===== MLP for Age: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.38      0.47      0.42      1602
#         20.0       0.29      0.30      0.29      1648
#         30.0       0.27      0.29      0.28      1615
#         40.0       0.28      0.24      0.26      1363
#         50.0       0.28      0.29      0.29      1191
#         60.0       0.28      0.19      0.23       740
#         70.0       0.27      0.14      0.18       319
#
#     accuracy                           0.30      8478
#    macro avg       0.29      0.27      0.28      8478
# weighted avg       0.30      0.30      0.30      8478
#          Model  Accuracy  Precision  Recall  F1-score
# 0  MLP for Age    0.3021     0.2977  0.3021    0.2974

# %%
fit_predict_gender_age_pipeline_with_soft_feature(MLPClassifier(hidden_layer_sizes=(128, 64, 32), max_iter=500, random_state=27, batch_size=32, learning_rate='adaptive', learning_rate_init=0.0005, alpha=0.001), KNeighborsClassifier(n_neighbors=5), "MLP for gender", "KNN for Age")
# Out:
# MLP for gender Gender Model - Validation Set Classification Report:
#                  precision    recall  f1-score   support
#
# female_feminine       0.88      0.92      0.90      3946
#  male_masculine       0.93      0.89      0.91      4532
#
#        accuracy                           0.90      8478
#       macro avg       0.90      0.90      0.90      8478
#    weighted avg       0.90      0.90      0.90      8478
#
# AUC-ROC for Gender Probabilities: 0.9553
# Log Loss for Gender Probabilities: 0.7519
# Fitting KNN for Age with gender probability feature
#
# ===== KNN for Age: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.64      0.82      0.72      7479
#         20.0       0.65      0.62      0.64      7684
#         30.0       0.66      0.66      0.66      7534
#         40.0       0.70      0.66      0.68      6359
#         50.0       0.74      0.66      0.70      5559
#         60.0       0.78      0.66      0.72      3457
#         70.0       0.80      0.72      0.76      1488
#
#     accuracy                           0.68     39560
#    macro avg       0.71      0.69      0.70     39560
# weighted avg       0.69      0.68      0.68     39560
#
#
# ===== KNN for Age: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.44      0.59      0.50      1602
#         20.0       0.37      0.35      0.36      1648
#         30.0       0.41      0.42      0.42      1615
#         40.0       0.47      0.45      0.46      1363
#         50.0       0.49      0.41      0.44      1191
#         60.0       0.54      0.43      0.48       740
#         70.0       0.55      0.43      0.48       319
#
#     accuracy                           0.44      8478
#    macro avg       0.47      0.44      0.45      8478
# weighted avg       0.45      0.44      0.44      8478
#          Model  Accuracy  Precision  Recall  F1-score
# 0  KNN for Age    0.4423     0.4456  0.4423    0.4405

# %%
fit_predict_gender_age_pipeline_with_soft_feature(
    MLPClassifier(hidden_layer_sizes=(128, 64, 32), max_iter=500, random_state=27, batch_size=32, learning_rate='adaptive', learning_rate_init=0.0005, alpha=0.001),
    MLPClassifier(hidden_layer_sizes=(128, 64, 32), max_iter=2000, random_state=27, batch_size=32, learning_rate='adaptive', learning_rate_init=0.0005, alpha=0.001, early_stopping=True, validation_fraction=0.1),
    "MLP for Gender", "MLP for Age"
)
# Out:
# MLP for Gender Gender Model - Validation Set Classification Report:
#                  precision    recall  f1-score   support
#
# female_feminine       0.88      0.92      0.90      3946
#  male_masculine       0.93      0.89      0.91      4532
#
#        accuracy                           0.90      8478
#       macro avg       0.90      0.90      0.90      8478
#    weighted avg       0.90      0.90      0.90      8478
#
# AUC-ROC for Gender Probabilities: 0.9553
# Log Loss for Gender Probabilities: 0.7519
# Fitting MLP for Age with gender probability feature
#
# ===== MLP for Age: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.60      0.72      0.66      7479
#         20.0       0.53      0.49      0.51      7684
#         30.0       0.51      0.55      0.53      7534
#         40.0       0.52      0.56      0.54      6359
#         50.0       0.60      0.54      0.57      5559
#         60.0       0.66      0.46      0.54      3457
#         70.0       0.71      0.54      0.61      1488
#
#     accuracy                           0.56     39560
#    macro avg       0.59      0.55      0.56     39560
# weighted avg       0.57      0.56      0.56     39560
#
#
# ===== MLP for Age: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#         10.0       0.39      0.46      0.43      1602
#         20.0       0.29      0.25      0.27      1648
#         30.0       0.27      0.30      0.29      1615
#         40.0       0.28      0.31      0.30      1363
#         50.0       0.32      0.29      0.30      1191
#         60.0       0.34      0.24      0.28       740
#         70.0       0.32      0.23      0.27       319
#
#     accuracy                           0.31      8478
#    macro avg       0.32      0.30      0.30      8478
# weighted avg       0.31      0.31      0.31      8478
#          Model  Accuracy  Precision  Recall  F1-score
# 0  MLP for Age    0.3149     0.3138  0.3149    0.3122

# %%
fit_predict_gender_age_pipeline_with_soft_feature(
    MLPClassifier(hidden_layer_sizes=(128, 64, 32), alpha=0.00005, activation="relu", batch_size=64, learning_rate_init=0.001, max_iter=3000,  learning_rate="adaptive", random_state=27),
    RandomForestClassifier(max_depth= 30, max_features="sqrt", min_samples_leaf=1, min_samples_split=3, n_estimators=300, random_state=27),
    "MLP for Gender", "Pre-Binned RF for Age",
    X_train=X_train, y_train_age=y_train["age_young_old"],y_train_gender=y_train["gender"], X_val=X_val, y_val_age=y_val["age_young_old"],y_val_gender=y_val["gender"],
    numerical=False, binning=identity
)
# Out:
# Fitting MLP for Gender on training set
#
# Predict probability of MLP for Gender on training set
#
# Predict probability of MLP for Gender on validation set
#
# MLP for Gender Gender Model - Validation Set Classification Report:
#                  precision    recall  f1-score   support
#
# female_feminine       0.91      0.90      0.91      4478
#  male_masculine       0.92      0.93      0.93      5722
#
#        accuracy                           0.92     10200
#       macro avg       0.92      0.92      0.92     10200
#    weighted avg       0.92      0.92      0.92     10200
#
# AUC-ROC for Gender Probabilities: 0.9658
# Log Loss for Gender Probabilities: 0.6918
# Fitting Pre-Binned RF for Age with gender probability feature
#
# ===== Pre-Binned RF for Age: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       1.00      1.00      1.00     20400
#        young       1.00      1.00      1.00     20400
#
#     accuracy                           1.00     40800
#    macro avg       1.00      1.00      1.00     40800
# weighted avg       1.00      1.00      1.00     40800
#
#
# ===== Pre-Binned RF for Age: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       0.70      0.77      0.73      5100
#        young       0.75      0.66      0.70      5100
#
#     accuracy                           0.72     10200
#    macro avg       0.72      0.72      0.72     10200
# weighted avg       0.72      0.72      0.72     10200
#                    Model  Accuracy  Precision  Recall  F1-score  QWK  MAE
# 0  Pre-Binned RF for Age    0.7186     0.7461  0.6627    0.7020  NaN  NaN

# %%
fit_predict_gender_age_pipeline_with_soft_feature(
    MLPClassifier(hidden_layer_sizes=(128, 64, 32), alpha=0.00005, activation="relu", batch_size=64, learning_rate_init=0.001, max_iter=3000,  learning_rate="adaptive", random_state=27),
    RandomForestClassifier(max_depth= 30, max_features="sqrt", min_samples_leaf=1, min_samples_split=3, n_estimators=300, random_state=27),
    "MLP for Gender", "Post-Binned RF for Age",
    X_train=X_train, y_train_age=y_train["age"],y_train_gender=y_train["gender"], X_val=X_val, y_val_age=y_val["age"],y_val_gender=y_val["gender"],
    numerical=False, binning=bin_age_young_old
)
# Out:
# Fitting MLP for Gender on training set
#
# Predict probability of MLP for Gender on training set
#
# Predict probability of MLP for Gender on validation set
#
# MLP for Gender Gender Model - Validation Set Classification Report:
#                  precision    recall  f1-score   support
#
# female_feminine       0.91      0.90      0.91      4478
#  male_masculine       0.92      0.93      0.93      5722
#
#        accuracy                           0.92     10200
#       macro avg       0.92      0.92      0.92     10200
#    weighted avg       0.92      0.92      0.92     10200
#
# AUC-ROC for Gender Probabilities: 0.9658
# Log Loss for Gender Probabilities: 0.6918
# Fitting Post-Binned RF for Age with gender probability feature
#
# ===== Post-Binned RF for Age: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       1.00      1.00      1.00     20400
#        young       1.00      1.00      1.00     20400
#
#     accuracy                           1.00     40800
#    macro avg       1.00      1.00      1.00     40800
# weighted avg       1.00      1.00      1.00     40800
#
#
# ===== Post-Binned RF for Age: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          old       0.76      0.57      0.65      5100
#        young       0.65      0.82      0.73      5100
#
#     accuracy                           0.69     10200
#    macro avg       0.70      0.69      0.69     10200
# weighted avg       0.70      0.69      0.69     10200
#                     Model  Accuracy  Precision  Recall  F1-score  QWK  MAE
# 0  Post-Binned RF for Age    0.6920     0.6534  0.8176    0.7264  NaN  NaN

# %%
y_train_multi = np.column_stack((y_train["age"], y_train["age_young_old_encoded"]))
y_val_multi = np.column_stack((y_val["age"], y_val["age_young_old_encoded"]))

# Base model (intentionally large)
base_clf = RandomForestClassifier(
    n_estimators=500,          # Big forest
    max_depth=20,            
    min_samples_split=2,       # Allow aggressive splitting
    min_samples_leaf=1,        # Smallest possible leaves
    max_features='sqrt',       # Good default for classification
    bootstrap=False,            # Enable bagging
    class_weight=None,         # Let it learn naturally, change to 'balanced' if needed
    oob_score=False,           # Could enable if bootstrap is True
    n_jobs=-1,                 # Use all CPUs
    random_state=42,           # For reproducibility
    verbose=0
)

# Wrap as multi-output
multi_clf = MultiOutputClassifier(base_clf)

fit_predict_gender_age_pipeline_with_soft_feature(
    MLPClassifier(hidden_layer_sizes=(128, 64, 32), alpha=0.00005, activation="relu", batch_size=64, learning_rate_init=0.001, max_iter=3000,  learning_rate="adaptive", random_state=27),
    multi_clf, "MLP for Gender", "Multi-Class for Age",
    X_train=X_train, y_train_age=y_train_multi, y_train_gender=y_train["gender"], X_val=X_val, y_val_age=y_val_multi, y_val_gender=y_val["gender"],
    numerical=False, binning=identity, multiclass=True
)
# Out:
# Fitting MLP for Gender on training set
#
# Predict probability of MLP for Gender on training set
#
# Predict probability of MLP for Gender on validation set
#
# MLP for Gender Gender Model - Validation Set Classification Report:
#                  precision    recall  f1-score   support
#
# female_feminine       0.91      0.90      0.91      4478
#  male_masculine       0.92      0.93      0.93      5722
#
#        accuracy                           0.92     10200
#       macro avg       0.92      0.92      0.92     10200
#    weighted avg       0.92      0.92      0.92     10200
#
# AUC-ROC for Gender Probabilities: 0.9658
# Log Loss for Gender Probabilities: 0.6918
# Fitting Multi-Class for Age with gender probability feature
#
# Predicting Multi-Class for Age on training set
#
# Predicting Multi-Class for Age on validation set
#
# ===== Multi-Class for Age: Training Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     20400
#          1.0       1.00      1.00      1.00     20400
#
#     accuracy                           1.00     40800
#    macro avg       1.00      1.00      1.00     40800
# weighted avg       1.00      1.00      1.00     40800
#
#
# ===== Multi-Class for Age: Validation Set =====
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.77      0.73      5100
#          1.0       0.74      0.67      0.71      5100
#
#     accuracy                           0.72     10200
#    macro avg       0.72      0.72      0.72     10200
# weighted avg       0.72      0.72      0.72     10200
#                  Model  Accuracy  Precision  Recall  F1-score  QWK  MAE
# 0  Multi-Class for Age    0.7205     0.7447  0.6710    0.7059  NaN  NaN
